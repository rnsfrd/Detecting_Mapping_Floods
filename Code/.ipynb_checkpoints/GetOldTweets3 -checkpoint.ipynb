# %% [markdown]
# # GetOldTweets3

# %% [markdown]
# ### Contents:
# - [Import Packages](#Import-Packages)
# - [Scrapping Tweets](#Scrapping-Tweets)
# - [Running with additional incidents/ locations](#Running-with-additional-incidents/-locations)

# %% [markdown]
# For this project we decided to focus on floods within the United States. To obtain flood data we scraped Tweets using the GetOldTweets3 API. These APIs allowed us to scrape tweets with certain keywords pertaining to floods, from a certain location, within a certain timeframe.

# %% [markdown]
# # Import Packages

# %%
import GetOldTweets3 as got
import pandas as pd

# %% [markdown]
# # Scrapping Tweets

# %% [markdown]
# Function for scrapping each state:
# Steps:
# 1. import tweets
# 2. created nested list of tweets and tweet attributes (username, text, date, retweets, favorites, mentions, hashtags, geo)
# 3. created dataframe of the list created in 2
# 4. created a target column = 0 or 1 depending on when we pulled from
# 5. created a user_split column that split usernames on ''
# 6. created 'user_text' column, which is the the 'user_split' column + 'Text' column.

# %%
def get_tweets(state, startdate, enddate):
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch("Flood")\
                                            .setSince(startdate)\
                                            .setUntil(enddate)\
                                            .setNear(state)\
                                            .setWithin("500mi")\
                                            .setMaxTweets(1000)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)
    text_tweets = [[#tw.id,
                #tw.permalink,
                tw.username,
                #tw.to,
                tw.text,
                tw.date,
                tw.retweets,
                tw.favorites,
                tw.mentions,
                tw.hashtags,
                tw.geo] for tw in tweet]
    df_state= pd.DataFrame(text_tweets, columns = ['User', 'Text', 'Date', 'Favorites', 'Retweets', 'Mentions',
                                                    'Hashtags'  , 'Geolocation'])
    return df_state

# %%
df_1 = get_tweets('Wisconsin', "2019-07-18", "2019-07-20")

# %%
df_1.shape
# Out:
# (350, 8)

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3   beganovic2021  Something about how crime will magically drop ...
# 4  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 22:17:13+00:00          0         0
# 4 2019-07-19 20:57:18+00:00          0         0
#
#    Hashtags Geolocation
# 0  #Respect
# 1
# 2
# 3
# 4

# %%
df_1['user_split'] = [df_1['User'][row].replace('_', ' ') for row in df_1.index]

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3   beganovic2021  Something about how crime will magically drop ...
# 4  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 22:17:13+00:00          0         0
# 4 2019-07-19 20:57:18+00:00          0         0
#
#    Hashtags Geolocation      user_split
# 0  #Respect                  Gabriettaa
# 1                           chaaasiti04
# 2                               JDenius
# 3                         beganovic2021
# 4                        RiskItAllRichy

# %%
df_1['User'].value_counts().head(25)
# Out:
# iembot_phi         24
# iembot_arx          8
# iembot_okx          8
# NWS_MountHolly      7
# TBWSirSpitta        7
# iembot_rlx          5
# USGS_TexasFlood     5
# iembot_hun          4
# manyhotzbeats       3
# iembot_jkl          3
# TotalTrafficNYC     3
# kpax512             3
# TxMichaelDugan      2
# LI_Weather516       2
# LensReality         2
# NWSTucson           2
# nwsjacksonky        2
# Bill_Flood          2
# spotternetwork      2
# iembot_iln          2
# iembot_twc          2
# CrystalDcreates     2
# NWSCharlestonWV     2
# runhildroeder       2
# udor_visualarts     2
# Name: User, dtype: int64

# %%
# 1 for it was a legitimate flood
df_1['target']= 1

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3   beganovic2021  Something about how crime will magically drop ...
# 4  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 22:17:13+00:00          0         0
# 4 2019-07-19 20:57:18+00:00          0         0
#
#    Hashtags Geolocation      user_split  target
# 0  #Respect                  Gabriettaa       1
# 1                           chaaasiti04       1
# 2                               JDenius       1
# 3                         beganovic2021       1
# 4                        RiskItAllRichy       1

# %%
# this user was referring to their album Flood so we needed to change that target 0
for i in df_1[df_1['User']== 'TBWSirSpitta'].index:
    df_1['target'][i]=0
df_1[df_1['User']=='TBWSirSpitta']
# Out:
# /Users/grace1916/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              User                                               Text  \
# 31   TBWSirSpitta  Don’t be that one mf that try to fuck up the v...
# 34   TBWSirSpitta  Go Pre Order “MY WAY” Now #LINKINBIO @GTDigita...
# 35   TBWSirSpitta  PRE ORDER #MYWAY The link is in my bio @applem...
# 174  TBWSirSpitta  So they ask me, “Yung boa, what you gone do th...
# 196  TBWSirSpitta  Ahhhh shit we done made it to the LAST DAY BEF...
# 206  TBWSirSpitta  Niggas couldn’t survive on this side TOMORROW ...
# 298  TBWSirSpitta  Wanna feel like this guy? Listen to #MYWAY And...
#
#                          Date  Favorites  Retweets  \
# 31  2019-07-19 03:16:55+00:00          2         2
# 34  2019-07-19 02:45:39+00:00          3         2
# 35  2019-07-19 02:40:52+00:00          2         1
# 174 2019-07-18 17:26:46+00:00          0         0
# 196 2019-07-18 13:26:47+00:00          0         0
# 206 2019-07-18 12:35:00+00:00          0         0
# 298 2019-07-18 01:01:48+00:00          1         0
#
#                         Mentions  \
# 31
# 34   @GTDigitalDIST @Goldtoes415
# 35                   @AppleMusic
# 174
# 196
# 206                  @CalvoMayne
# 298
#
#                                               Hashtags Geolocation  \
# 31   #MYWAY #LINKINBIO #TooBusyWinning #FLOOD #FOE ...
# 34   #LINKINBIO #TooBusyWinning #MYWAY #FLOOD #FOE ...
# 35           #MYWAY #FLOOD #TooBusyWinning #FLOOD #FOE
# 174  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
# 196          #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID
# 206  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
# 298  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
#
#        user_split  target
# 31   TBWSirSpitta       0
# 34   TBWSirSpitta       0
# 35   TBWSirSpitta       0
# 174  TBWSirSpitta       0
# 196  TBWSirSpitta       0
# 206  TBWSirSpitta       0
# 298  TBWSirSpitta       0

# %%
# looking at a false positive 
df_1['Text'][0]
# Out:
# "Nice to have a positive story about big cats for a change! #Respect India floods: Tired tiger takes nap in resident's bed via @BBCWorld https://www.bbc.com/news/world-asia-india-49041722 @BigCatRescue"

# %%
# changing the false positive to a target of one 
df_1['target'][0]=0
# Out:
# /Users/grace1916/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(df_1['user_split'][0])
# Out:
# 10

# %%
df_1[df_1['user_split'].str.find('iembot')>-1]
# Out:
#            User                                               Text  \
# 11   iembot_sgf  At 6:15 PM CDT, 2 WNW Rolla [Phelps Co, MO] PU...
# 15   iembot_arx  At 3:00 AM CDT, Stockton [Winona Co, MN] EMERG...
# 16   iembot_arx  At 7:05 AM CDT, 2 NE Lewiston [Winona Co, MN] ...
# 18   iembot_arx  At 5:22 AM CDT, 1 W Coon Valley [Vernon Co, WI...
# 19   iembot_arx  At 4:13 AM CDT, 1 N Viroqua [Vernon Co, WI] LA...
# ..          ...                                                ...
# 292  iembot_lsx  At 8:05 PM CDT, Gerald [Franklin Co, MO] 911 C...
# 293  iembot_lsx  At 8:05 PM CDT, NEW Haven [Franklin Co, MO] 91...
# 340  iembot_phi  At 8:06 PM EDT, 1 SSW Exeter TWP [Berks Co, PA...
# 347  iembot_meg  At 7:45 AM CDT, 8 ENE Tupelo [Lee Co, MS] BROA...
# 348  iembot_phi  At 7:53 PM EDT, Douglassville [Berks Co, PA] F...
#
#                          Date  Favorites  Retweets Mentions Hashtags  \
# 11  2019-07-19 13:53:26+00:00          1         0
# 15  2019-07-19 12:07:40+00:00          0         0
# 16  2019-07-19 12:07:39+00:00          0         0
# 18  2019-07-19 10:28:15+00:00          0         0
# 19  2019-07-19 09:16:25+00:00          0         0
# ..                        ...        ...       ...      ...      ...
# 292 2019-07-18 01:14:37+00:00          0         0
# 293 2019-07-18 01:13:45+00:00          0         0
# 340 2019-07-18 00:07:49+00:00          0         0
# 347 2019-07-18 00:01:43+00:00          0         0
# 348 2019-07-18 00:01:29+00:00          2         1
#
#     Geolocation  user_split  target
# 11               iembot sgf       1
# 15               iembot arx       1
# 16               iembot arx       1
# 18               iembot arx       1
# 19               iembot arx       1
# ..          ...         ...     ...
# 292              iembot lsx       1
# 293              iembot lsx       1
# 340              iembot phi       1
# 347              iembot meg       1
# 348              iembot phi       1
#
# [68 rows x 10 columns]

# %%
df_1['user_text'] = df_1['user_split']+' ' + df_1['Text']
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3   beganovic2021  Something about how crime will magically drop ...
# 4  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 22:17:13+00:00          0         0
# 4 2019-07-19 20:57:18+00:00          0         0
#
#    Hashtags Geolocation      user_split  target  \
# 0  #Respect                  Gabriettaa       0
# 1                           chaaasiti04       1
# 2                               JDenius       1
# 3                         beganovic2021       1
# 4                        RiskItAllRichy       1
#
#                                            user_text
# 0  Gabriettaa Nice to have a positive story about...
# 1  chaaasiti04 my dad just told me to flood my ca...
# 2     JDenius Happy B-day Reggie, from the office!!!
# 3  beganovic2021 Something about how crime will m...
# 4  RiskItAllRichy Lol mine too. I’ve been avoidin...

# %%
df_0 = get_tweets('Wisconsin', "2019-12-16", "2019-12-25")

# %%
df_0['user_split'] = [df_0['User'][row].replace('_', ' ') for row in df_0.index]

# %%
df_0['user_text'] = df_0['user_split']+' ' + df_0['Text']
df_0.head()
# Out:
#              User                                               Text  \
# 0      jimistlboy  It’s an enormous injustice and it hurts my Car...
# 1  EdwardWellence  Im sorry to say some people wont find happines...
# 2        maya0818     Floods, fog create Christmas Eve travel havoc
# 3   morganabigail  Drinking a Bar Baby Blonde by @GreatFloodBeer ...
# 4    LitVolBangor  Merry Jólabókaflóð, or “Yule Book Flood"! In I...
#
#                        Date  Favorites  Retweets         Mentions  \
# 0 2019-12-24 23:29:02+00:00          1         2
# 1 2019-12-24 23:12:59+00:00          2         7
# 2 2019-12-24 23:07:44+00:00          0         0
# 3 2019-12-24 23:03:37+00:00          0         2  @GreatFloodBeer
# 4 2019-12-24 22:46:56+00:00          6        12
#
#                     Hashtags Geolocation      user_split  \
# 0                                             jimistlboy
# 1                                         EdwardWellence
# 2                                               maya0818
# 3                                          morganabigail
# 4  #delightful #ChristmasEve                LitVolBangor
#
#                                            user_text
# 0  jimistlboy It’s an enormous injustice and it h...
# 1  EdwardWellence Im sorry to say some people won...
# 2  maya0818 Floods, fog create Christmas Eve trav...
# 3  morganabigail Drinking a Bar Baby Blonde by @G...
# 4  LitVolBangor Merry Jólabókaflóð, or “Yule Book...

# %%
df_0['target']=0

# %%
df_WI = pd.concat([df_1, df_0], ignore_index = True)
df_WI
# Out:
# /Users/grace1916/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                           Date  Favorites Geolocation  \
# 0    2019-07-19 22:40:31+00:00          0
# 1    2019-07-19 22:26:34+00:00          0
# 2    2019-07-19 22:19:05+00:00          1
# 3    2019-07-19 22:17:13+00:00          0
# 4    2019-07-19 20:57:18+00:00          0
# ...                        ...        ...         ...
# 1345 2019-12-16 20:57:46+00:00          0
# 1346 2019-12-16 20:57:46+00:00          7
# 1347 2019-12-16 20:45:44+00:00          0
# 1348 2019-12-16 20:31:51+00:00          0
# 1349 2019-12-16 20:31:27+00:00          6
#
#                       Hashtags                 Mentions  Retweets  \
# 0                     #Respect  @BBCWorld @BigCatRescue         1
# 1                                                               0
# 2                                                               2
# 3                                                               0
# 4                                                               0
# ...                        ...                      ...       ...
# 1345                                                            0
# 1346  #12NewsNow #StormTracker                                  7
# 1347       #WoooPigSooieAnyway                                  1
# 1348                                                            1
# 1349                                                            5
#
#                                                    Text            User  \
# 0     Nice to have a positive story about big cats f...      Gabriettaa
# 1     my dad just told me to flood my car so I can g...     chaaasiti04
# 2                Happy B-day Reggie, from the office!!!         JDenius
# 3     Something about how crime will magically drop ...   beganovic2021
# 4     Lol mine too. I’ve been avoiding floods for th...  RiskItAllRichy
# ...                                                 ...             ...
# 1345  The Flash Flood Warning is in effect until 4:3...  TylerSeggerman
# 1346  FLASH FLOOD WARNING | Emergency personnel are ...  TylerSeggerman
# 1347  Exactly. Until then, flood his account with su...   timothy_mosby
# 1348  There’s two things in the Bible I absolutely c...           1yson
# 1349  Flash Flood Warning including Beaumont TX unti...  NWSLakeCharles
#
#       target      user_split  \
# 0          0      Gabriettaa
# 1          1     chaaasiti04
# 2          1         JDenius
# 3          1   beganovic2021
# 4          1  RiskItAllRichy
# ...      ...             ...
# 1345       0  TylerSeggerman
# 1346       0  TylerSeggerman
# 1347       0   timothy mosby
# 1348       0           1yson
# 1349       0  NWSLakeCharles
#
#                                               user_text
# 0     Gabriettaa Nice to have a positive story about...
# 1     chaaasiti04 my dad just told me to flood my ca...
# 2        JDenius Happy B-day Reggie, from the office!!!
# 3     beganovic2021 Something about how crime will m...
# 4     RiskItAllRichy Lol mine too. I’ve been avoidin...
# ...                                                 ...
# 1345  TylerSeggerman The Flash Flood Warning is in e...
# 1346  TylerSeggerman FLASH FLOOD WARNING | Emergency...
# 1347  timothy mosby Exactly. Until then, flood his a...
# 1348  1yson There’s two things in the Bible I absolu...
# 1349  NWSLakeCharles Flash Flood Warning including B...
#
# [1350 rows x 11 columns]

# %%
df_WI['location'] = 'WI'
df_WI.head()
# Out:
#                        Date  Favorites Geolocation  Hashtags  \
# 0 2019-07-19 22:40:31+00:00          0              #Respect
# 1 2019-07-19 22:26:34+00:00          0
# 2 2019-07-19 22:19:05+00:00          1
# 3 2019-07-19 22:17:13+00:00          0
# 4 2019-07-19 20:57:18+00:00          0
#
#                   Mentions  Retweets  \
# 0  @BBCWorld @BigCatRescue         1
# 1                                  0
# 2                                  2
# 3                                  0
# 4                                  0
#
#                                                 Text            User  target  \
# 0  Nice to have a positive story about big cats f...      Gabriettaa       0
# 1  my dad just told me to flood my car so I can g...     chaaasiti04       1
# 2             Happy B-day Reggie, from the office!!!         JDenius       1
# 3  Something about how crime will magically drop ...   beganovic2021       1
# 4  Lol mine too. I’ve been avoiding floods for th...  RiskItAllRichy       1
#
#        user_split                                          user_text location
# 0      Gabriettaa  Gabriettaa Nice to have a positive story about...       WI
# 1     chaaasiti04  chaaasiti04 my dad just told me to flood my ca...       WI
# 2         JDenius     JDenius Happy B-day Reggie, from the office!!!       WI
# 3   beganovic2021  beganovic2021 Something about how crime will m...       WI
# 4  RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...       WI

# %%
#df_WI.to_csv('df_WI.csv')

# %%
pd.read_csv('../Datasets/df_WI.csv')
# Out:
#      Unnamed: 0                       Date  Favorites  Geolocation  \
# 0             0  2019-07-19 22:40:31+00:00          0          NaN
# 1             1  2019-07-19 22:26:34+00:00          0          NaN
# 2             2  2019-07-19 22:19:05+00:00          1          NaN
# 3             3  2019-07-19 22:17:13+00:00          0          NaN
# 4             4  2019-07-19 20:57:18+00:00          0          NaN
# ..          ...                        ...        ...          ...
# 698         698  2019-12-21 00:15:59+00:00          0          NaN
# 699         699  2019-12-20 23:52:23+00:00          1          NaN
# 700         700  2019-12-20 23:29:12+00:00          0          NaN
# 701         701  2019-12-20 23:06:57+00:00          0          NaN
# 702         702  2019-12-20 23:01:21+00:00          0          NaN
#
#                                 HashTags                 Mentions  Retweets  \
# 0                               #Respect  @BBCWorld @BigCatRescue         1
# 1                                    NaN                      NaN         0
# 2                                    NaN                      NaN         2
# 3                                    NaN                      NaN         0
# 4                                    NaN                      NaN         0
# ..                                   ...                      ...       ...
# 698  #StarWarsRiseofSkywalker #StarWars9                      NaN         6
# 699                         #flood #NDMA                      NaN         0
# 700                                  NaN                      NaN         0
# 701                                  NaN                      NaN         1
# 702                                  NaN                      NaN        30
#
#                                                   Text             User  \
# 0    Nice to have a positive story about big cats f...       Gabriettaa
# 1    my dad just told me to flood my car so I can g...      chaaasiti04
# 2               Happy B-day Reggie, from the office!!!          JDenius
# 3    Something about how crime will magically drop ...    beganovic2021
# 4    Lol mine too. I’ve been avoiding floods for th...   RiskItAllRichy
# ..                                                 ...              ...
# 698  What’s the o/u for how many times I’ll flood t...   NotTheFakeWags
# 699  This is a sample message from a disaster victi...   david_hadaller
# 700  Just arriving so warm ups complete and flood d...  lhhslionshockey
# 701  Does it flood in Brandon? Wonder if this thing...   aggieloveseggs
# 702  Just turned in the Grand Cherokee Trailhawk. 3...   SpeedSportLife
#
#      target       user_split  \
# 0         0       Gabriettaa
# 1         1      chaaasiti04
# 2         1          JDenius
# 3         1    beganovic2021
# 4         1   RiskItAllRichy
# ..      ...              ...
# 698       0   NotTheFakeWags
# 699       0   david hadaller
# 700       0  lhhslionshockey
# 701       0   aggieloveseggs
# 702       0   SpeedSportLife
#
#                                              user_text location
# 0    Gabriettaa Nice to have a positive story about...       WI
# 1    chaaasiti04 my dad just told me to flood my ca...       WI
# 2       JDenius Happy B-day Reggie, from the office!!!       WI
# 3    beganovic2021 Something about how crime will m...       WI
# 4    RiskItAllRichy Lol mine too. I’ve been avoidin...       WI
# ..                                                 ...      ...
# 698  NotTheFakeWags What’s the o/u for how many tim...       WI
# 699  david hadaller This is a sample message from a...       WI
# 700  lhhslionshockey Just arriving so warm ups comp...       WI
# 701  aggieloveseggs Does it flood in Brandon? Wonde...       WI
# 702  SpeedSportLife Just turned in the Grand Cherok...       WI
#
# [703 rows x 13 columns]

# %% [markdown]
# ### Running with additional incidents/ locations

# %% [markdown]
# We then scrapped Texas and Iowa for dates where a flood did occur and dates where a flood did not occur.

# %%
df_1_TX = get_tweets('Texas', "2016-05-22", "2016-06-24")

# %%
df_1_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags Geolocation
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK

# %%
df_1_TX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# User           1000 non-null object
# Text           1000 non-null object
# Date           1000 non-null datetime64[ns, UTC]
# Favorites      1000 non-null int64
# Retweets       1000 non-null int64
# Mentions       1000 non-null object
# Hashtags       1000 non-null object
# Geolocation    1000 non-null object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
df_1_TX['Geolocation'].unique()
# Out:
# array([''], dtype=object)

# %%
df_1_TX['user_split'] = [df_1_TX['User'][row].replace('_', ' ') for row in df_1_TX.index]
df_1_TX['user_text'] = df_1_TX['user_split']+' ' + df_1_TX['Text']
df_1_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK
#
#   Geolocation  user_split                                          user_text
# 0              iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1              iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2              iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3              iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4              iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...

# %%
df_1_TX['target']=1
df_1_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK
#
#   Geolocation  user_split                                          user_text  \
# 0              iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1              iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2              iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3              iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4              iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_0_TX = get_tweets('Texas', "2016-08-22", "2016-09-24")

# %%
df_0_TX.head()
# Out:
#               User                                               Text  \
# 0   GODFATHERofICE  And it begins/has begun #ruts #snow #frozenHan...
# 1  NotMadOnline247  "Oh, Ophelia, you've been on my mind girl sinc...
# 2         tim_kite  Charity beer for flood relief! Come get some! ...
# 3   kerascreations  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4  adv_w_nancylynn  Come to the McCallie tailgate tonight and supp...
#
#                        Date  Favorites  Retweets       Mentions  \
# 0 2016-09-23 23:21:49+00:00          0         0
# 1 2016-09-23 22:58:22+00:00          0         1
# 2 2016-09-23 22:50:47+00:00          0         0  @TheAbitaBeer
# 3 2016-09-23 22:28:33+00:00          0         1
# 4 2016-09-23 21:39:13+00:00          0         1
#
#                                             Hashtags Geolocation
# 0       #ruts #snow #frozenHands #floods #doubleZams
# 1
# 2
# 3  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4

# %%
df_0_TX['user_split'] = [df_0_TX['User'][row].replace('_', ' ') for row in df_0_TX.index]
df_0_TX['user_text'] = df_0_TX['user_split']+' ' + df_0_TX['Text']
df_0_TX.head()
# Out:
#               User                                               Text  \
# 0   GODFATHERofICE  And it begins/has begun #ruts #snow #frozenHan...
# 1  NotMadOnline247  "Oh, Ophelia, you've been on my mind girl sinc...
# 2         tim_kite  Charity beer for flood relief! Come get some! ...
# 3   kerascreations  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4  adv_w_nancylynn  Come to the McCallie tailgate tonight and supp...
#
#                        Date  Favorites  Retweets       Mentions  \
# 0 2016-09-23 23:21:49+00:00          0         0
# 1 2016-09-23 22:58:22+00:00          0         1
# 2 2016-09-23 22:50:47+00:00          0         0  @TheAbitaBeer
# 3 2016-09-23 22:28:33+00:00          0         1
# 4 2016-09-23 21:39:13+00:00          0         1
#
#                                             Hashtags Geolocation  \
# 0       #ruts #snow #frozenHands #floods #doubleZams
# 1
# 2
# 3  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4
#
#         user_split                                          user_text
# 0   GODFATHERofICE  GODFATHERofICE And it begins/has begun #ruts #...
# 1  NotMadOnline247  NotMadOnline247 "Oh, Ophelia, you've been on m...
# 2         tim kite  tim kite Charity beer for flood relief! Come g...
# 3   kerascreations  kerascreations #cedarrapids #ellisharbor #cr20...
# 4  adv w nancylynn  adv w nancylynn Come to the McCallie tailgate ...

# %%
df_0_TX['target']=0
df_0_TX.head()
# Out:
#               User                                               Text  \
# 0   GODFATHERofICE  And it begins/has begun #ruts #snow #frozenHan...
# 1  NotMadOnline247  "Oh, Ophelia, you've been on my mind girl sinc...
# 2         tim_kite  Charity beer for flood relief! Come get some! ...
# 3   kerascreations  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4  adv_w_nancylynn  Come to the McCallie tailgate tonight and supp...
#
#                        Date  Favorites  Retweets       Mentions  \
# 0 2016-09-23 23:21:49+00:00          0         0
# 1 2016-09-23 22:58:22+00:00          0         1
# 2 2016-09-23 22:50:47+00:00          0         0  @TheAbitaBeer
# 3 2016-09-23 22:28:33+00:00          0         1
# 4 2016-09-23 21:39:13+00:00          0         1
#
#                                             Hashtags Geolocation  \
# 0       #ruts #snow #frozenHands #floods #doubleZams
# 1
# 2
# 3  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4
#
#         user_split                                          user_text  target
# 0   GODFATHERofICE  GODFATHERofICE And it begins/has begun #ruts #...       0
# 1  NotMadOnline247  NotMadOnline247 "Oh, Ophelia, you've been on m...       0
# 2         tim kite  tim kite Charity beer for flood relief! Come g...       0
# 3   kerascreations  kerascreations #cedarrapids #ellisharbor #cr20...       0
# 4  adv w nancylynn  adv w nancylynn Come to the McCallie tailgate ...       0

# %%
df_TX = pd.concat([df_1_TX, df_0_TX], axis = 0)

# %%
df_TX['location'] = 'TX'
df_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK
#
#   Geolocation  user_split                                          user_text  \
# 0              iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1              iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2              iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3              iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4              iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...
#
#    target location
# 0       1       TX
# 1       1       TX
# 2       1       TX
# 3       1       TX
# 4       1       TX

# %%
df_TX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 999
# Data columns (total 12 columns):
# User           2000 non-null object
# Text           2000 non-null object
# Date           2000 non-null datetime64[ns, UTC]
# Favorites      2000 non-null int64
# Retweets       2000 non-null int64
# Mentions       2000 non-null object
# Hashtags       2000 non-null object
# Geolocation    2000 non-null object
# user_split     2000 non-null object
# user_text      2000 non-null object
# target         2000 non-null int64
# location       2000 non-null object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 203.1+ KB

# %%
#df_TX.to_csv('df_TX.csv')

# %%
pd.read_csv('../Datasets/df_TX.csv')
# Out:
#       Unnamed: 0            User  \
# 0              0      LisaAbeyta
# 1              1      iembot_rlx
# 2              2      iembot_rlx
# 3              3      iembot_rlx
# 4              4      iembot_rlx
# ...          ...             ...
# 1995         995     CharlotteCP
# 1996         996  NWSTallahassee
# 1997         997     BLifeAldine
# 1998         998    Futureteller
# 1999         999         ClayDix
#
#                                                    Text  \
# 0     Flash flood warning until 7 PM #nmwx #nm @Albu...
# 1     At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 2     At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 3     At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 4     At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# ...                                                 ...
# 1995  Flash flood watch for Charlotte and eastward u...
# 1996   Move to higher ground! Flash Flood Warning in...
# 1997  Help arrives for Greenspoint flood victi http:...
# 1998  W my fellow Capital Correspondents raising $fo...
# 1999  Flood party @Charleston, South Carolina https:...
#
#                            Date  Favorites  Retweets         Mentions  \
# 0     2016-06-23 23:59:36+00:00          0         0              NaN
# 1     2016-06-23 23:53:45+00:00          0         0              NaN
# 2     2016-06-23 23:50:46+00:00          0         0              NaN
# 3     2016-06-23 23:48:01+00:00          0         0              NaN
# 4     2016-06-23 22:27:16+00:00          0         0              NaN
# ...                         ...        ...       ...              ...
# 1995  2016-09-02 09:56:07+00:00          0         0  @SarahFortnerWx
# 1996  2016-09-02 05:19:09+00:00         56        18              NaN
# 1997  2016-09-02 04:47:49+00:00          0         0              NaN
# 1998  2016-09-02 02:49:25+00:00          0         3              NaN
# 1999  2016-09-02 02:46:37+00:00          0         0              NaN
#
#        HashTags  Geolocation      user_split  \
# 0     #nmwx #nm          NaN      LisaAbeyta
# 1          #RLX          NaN      iembot rlx
# 2          #RLX          NaN      iembot rlx
# 3          #RLX          NaN      iembot rlx
# 4          #RLX          NaN      iembot rlx
# ...         ...          ...             ...
# 1995        NaN          NaN     CharlotteCP
# 1996        NaN          NaN  NWSTallahassee
# 1997        NaN          NaN     BLifeAldine
# 1998        NaN          NaN    Futureteller
# 1999        NaN          NaN         ClayDix
#
#                                               user_text  target location
# 0     LisaAbeyta Flash flood warning until 7 PM #nmw...       1       TX
# 1     iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...       1       TX
# 2     iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...       1       TX
# 3     iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...       1       TX
# 4     iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...       1       TX
# ...                                                 ...     ...      ...
# 1995  CharlotteCP Flash flood watch for Charlotte an...       0       TX
# 1996  NWSTallahassee  Move to higher ground! Flash F...       0       TX
# 1997  BLifeAldine Help arrives for Greenspoint flood...       0       TX
# 1998  Futureteller W my fellow Capital Correspondent...       0       TX
# 1999  ClayDix Flood party @Charleston, South Carolin...       0       TX
#
# [2000 rows x 13 columns]

# %% [markdown]
# y=1 data, Iowa

# %%
df_1_IA = get_tweets('Iowa', "2016-09-21", "2016-10-03")

# %%
df_1_IA['user_split'] = [df_1_IA['User'][row].replace('_', ' ') for row in df_1_IA.index]
df_1_IA['user_text'] = df_1_IA['user_split']+' ' + df_1_IA['Text']
df_1_IA.head()
# Out:
#            User                                               Text  \
# 0    iembot_grr  At 7:30 PM, 3 SW Clarksville [Ionia Co, MI] 91...
# 1  chriswhetlor  Alien Crop Circles, sign of the flood, or poss...
# 2       NickFry  Don't forget!!! TONIGHT! WV Flood Benefit Conc...
# 3    iembot_lwx  At 3:13 PM, 1 SW Breton BAY [St. Marys Co, MD]...
# 4  Mzzbesttbest  My Sisters keeps Telling me not to Flood and S...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-10-02 00:02:34+00:00          0         0              #GRR
# 1 2016-10-01 22:42:21+00:00          0         0
# 2 2016-10-01 21:52:44+00:00          0         0
# 3 2016-10-01 19:15:32+00:00          0         0              #LWX
# 4 2016-10-01 17:58:03+00:00          1         1
#
#   Geolocation    user_split                                          user_text
# 0                iembot grr  iembot grr At 7:30 PM, 3 SW Clarksville [Ionia...
# 1              chriswhetlor  chriswhetlor Alien Crop Circles, sign of the f...
# 2                   NickFry  NickFry Don't forget!!! TONIGHT! WV Flood Bene...
# 3                iembot lwx  iembot lwx At 3:13 PM, 1 SW Breton BAY [St. Ma...
# 4              Mzzbesttbest  Mzzbesttbest My Sisters keeps Telling me not t...

# %%
df_1_IA['target']=1
df_1_IA.head()
# Out:
#            User                                               Text  \
# 0    iembot_grr  At 7:30 PM, 3 SW Clarksville [Ionia Co, MI] 91...
# 1  chriswhetlor  Alien Crop Circles, sign of the flood, or poss...
# 2       NickFry  Don't forget!!! TONIGHT! WV Flood Benefit Conc...
# 3    iembot_lwx  At 3:13 PM, 1 SW Breton BAY [St. Marys Co, MD]...
# 4  Mzzbesttbest  My Sisters keeps Telling me not to Flood and S...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-10-02 00:02:34+00:00          0         0              #GRR
# 1 2016-10-01 22:42:21+00:00          0         0
# 2 2016-10-01 21:52:44+00:00          0         0
# 3 2016-10-01 19:15:32+00:00          0         0              #LWX
# 4 2016-10-01 17:58:03+00:00          1         1
#
#   Geolocation    user_split  \
# 0                iembot grr
# 1              chriswhetlor
# 2                   NickFry
# 3                iembot lwx
# 4              Mzzbesttbest
#
#                                            user_text  target
# 0  iembot grr At 7:30 PM, 3 SW Clarksville [Ionia...       1
# 1  chriswhetlor Alien Crop Circles, sign of the f...       1
# 2  NickFry Don't forget!!! TONIGHT! WV Flood Bene...       1
# 3  iembot lwx At 3:13 PM, 1 SW Breton BAY [St. Ma...       1
# 4  Mzzbesttbest My Sisters keeps Telling me not t...       1

# %%
df_1_IA['Text'][2]
# Out:
# "Don't forget!!! TONIGHT! WV Flood Benefit Concert Barboursville Park in Barboursville,… https://www.instagram.com/p/BLCTwi4At58/"

# %%
df_1_IA.head(25)
# Out:
#                User                                               Text  \
# 0        iembot_grr  At 7:30 PM, 3 SW Clarksville [Ionia Co, MI] 91...
# 1      chriswhetlor  Alien Crop Circles, sign of the flood, or poss...
# 2           NickFry  Don't forget!!! TONIGHT! WV Flood Benefit Conc...
# 3        iembot_lwx  At 3:13 PM, 1 SW Breton BAY [St. Marys Co, MD]...
# 4      Mzzbesttbest  My Sisters keeps Telling me not to Flood and S...
# 5    favourcookieco  takeadumpontrump2016@Gmail.com Flood his inbox...
# 6      HeelingAHart  And GN/GM... This concludes the clearing of my...
# 7   LaffHousePhilly  datgirlcomedy and hope.flood #philly #laffhous...
# 8   LaffHousePhilly  hope.flood &amp; datgirlcomedy killed it tonig...
# 9          njframer  VERY IMPORTANT to all in the Windsor/Tecumseh ...
# 10  Chaotic_Freedom  intersection of King and Union#sandbags #flood...
# 11       iembot_akq  At 4:15 PM, 2 E Wharfs Store [Dinwiddie Co, VA...
# 12       iembot_akq  At 5:30 PM, 1 W Petersburg National [City Of P...
# 13   NWSWakefieldVA   Move to higher ground! Flash Flood Warning in...
# 14   NWSWakefieldVA   Move to higher ground! Flash Flood Warning in...
# 15    erickasvision  This is our look as if right now. Flash flood ...
# 16   NWSWakefieldVA   Move to higher ground! Flash Flood Warning in...
# 17   NWSWakefieldVA   Move to higher ground! Flash Flood Warning in...
# 18    noteworthyrun  At bike and bag check-in. Water is still crazy...
# 19       iembot_rnk  At 1:00 PM, 2 W Stewartsville [Bedford Co, VA]...
# 20        A_L_I_XXX  I apologize now for all of the beautiful pictu...
# 21     jerrellddean   "And Oh the joy that floods my soul!" . To ta...
# 22        BravoSayz  They drove through floods, rain, more rain, mo...
# 23       NWSRaleigh   Move to higher ground! Flash Flood Warning co...
# 24       NWSRaleigh   Move to higher ground! Flash Flood Warning co...
#
#                         Date  Favorites  Retweets Mentions  \
# 0  2016-10-02 00:02:34+00:00          0         0
# 1  2016-10-01 22:42:21+00:00          0         0
# 2  2016-10-01 21:52:44+00:00          0         0
# 3  2016-10-01 19:15:32+00:00          0         0
# 4  2016-10-01 17:58:03+00:00          1         1
# 5  2016-10-01 17:45:43+00:00          0         0
# 6  2016-10-01 06:16:09+00:00          0         0
# 7  2016-10-01 03:22:57+00:00          0         1
# 8  2016-10-01 03:09:26+00:00          1         0
# 9  2016-10-01 01:57:57+00:00          0         0
# 10 2016-10-01 00:08:02+00:00          0         0
# 11 2016-09-30 23:22:04+00:00          0         0
# 12 2016-09-30 23:18:46+00:00          0         0
# 13 2016-09-30 21:53:34+00:00          2         0
# 14 2016-09-30 20:56:20+00:00          1         1
# 15 2016-09-30 20:36:25+00:00          0         0
# 16 2016-09-30 20:34:27+00:00          2         0
# 17 2016-09-30 19:42:02+00:00          1         1
# 18 2016-09-30 18:13:00+00:00          0         1
# 19 2016-09-30 17:40:35+00:00          0         0
# 20 2016-09-30 17:39:05+00:00          0         0
# 21 2016-09-30 17:22:52+00:00          0         0
# 22 2016-09-30 17:22:38+00:00          1         1
# 23 2016-09-30 15:42:25+00:00          1         0
# 24 2016-09-30 15:38:07+00:00          0         0
#
#                                            Hashtags Geolocation  \
# 0                                              #GRR
# 1
# 2
# 3                                              #LWX
# 4
# 5
# 6
# 7   #philly #laffhouseisback #LAFFHOUSE #comdeyvets
# 8                       #laffhouseisback #laffhouse
# 9
# 10                                 #flood #flooding
# 11                                             #AKQ
# 12                                             #AKQ
# 13
# 14
# 15
# 16
# 17
# 18
# 19                                             #RNK
# 20
# 21
# 22
# 23
# 24
#
#          user_split                                          user_text  target
# 0        iembot grr  iembot grr At 7:30 PM, 3 SW Clarksville [Ionia...       1
# 1      chriswhetlor  chriswhetlor Alien Crop Circles, sign of the f...       1
# 2           NickFry  NickFry Don't forget!!! TONIGHT! WV Flood Bene...       1
# 3        iembot lwx  iembot lwx At 3:13 PM, 1 SW Breton BAY [St. Ma...       1
# 4      Mzzbesttbest  Mzzbesttbest My Sisters keeps Telling me not t...       1
# 5    favourcookieco  favourcookieco takeadumpontrump2016@Gmail.com ...       1
# 6      HeelingAHart  HeelingAHart And GN/GM... This concludes the c...       1
# 7   LaffHousePhilly  LaffHousePhilly datgirlcomedy and hope.flood #...       1
# 8   LaffHousePhilly  LaffHousePhilly hope.flood &amp; datgirlcomedy...       1
# 9          njframer  njframer VERY IMPORTANT to all in the Windsor/...       1
# 10  Chaotic Freedom  Chaotic Freedom intersection of King and Union...       1
# 11       iembot akq  iembot akq At 4:15 PM, 2 E Wharfs Store [Dinwi...       1
# 12       iembot akq  iembot akq At 5:30 PM, 1 W Petersburg National...       1
# 13   NWSWakefieldVA  NWSWakefieldVA  Move to higher ground! Flash F...       1
# 14   NWSWakefieldVA  NWSWakefieldVA  Move to higher ground! Flash F...       1
# 15    erickasvision  erickasvision This is our look as if right now...       1
# 16   NWSWakefieldVA  NWSWakefieldVA  Move to higher ground! Flash F...       1
# 17   NWSWakefieldVA  NWSWakefieldVA  Move to higher ground! Flash F...       1
# 18    noteworthyrun  noteworthyrun At bike and bag check-in. Water ...       1
# 19       iembot rnk  iembot rnk At 1:00 PM, 2 W Stewartsville [Bedf...       1
# 20        A L I XXX  A L I XXX I apologize now for all of the beaut...       1
# 21     jerrellddean  jerrellddean  "And Oh the joy that floods my s...       1
# 22        BravoSayz  BravoSayz They drove through floods, rain, mor...       1
# 23       NWSRaleigh  NWSRaleigh  Move to higher ground! Flash Flood...       1
# 24       NWSRaleigh  NWSRaleigh  Move to higher ground! Flash Flood...       1

# %%
df_1_IA['target'][[0,1,2,4,5,22,23, 24]]=0
# Out:
# /Users/grace1916/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1_IA['target'].value_counts()
# Out:
# 1    634
# 0      8
# Name: target, dtype: int64

# %% [markdown]
# y=0, Iowa

# %%
# y= 0, Iowa tweets
# change function to max tweet of 660 from 1000 to balance it out
df_0_IA = get_tweets('Iowa', "2017-09-01", "2017-10-21")

# %%
df_0_IA['user_split'] = [df_0_IA['User'][row].replace('_', ' ') for row in df_0_IA.index]
df_0_IA['user_text'] = df_0_IA['user_split']+' ' + df_0_IA['Text']
df_0_IA.head()
# Out:
#               User                                               Text  \
# 0     jimosborne98      Lol! The flood of lies just keeps on rolling!
# 1   timinhollywood  Excuse me while I flood my timeline with Howar...
# 2       iembot_hgx  At 6:00 AM, 3 W League City [Galveston Co, TX]...
# 3       NWSHouston  Flash Flood Warning including League City TX, ...
# 4  USGS_TexasFlood  #USGS08030500 - Sabine Rv nr Ruliff, TX is abo...
#
#                        Date  Favorites  Retweets Mentions       Hashtags  \
# 0 2017-10-20 22:49:49+00:00          0         0
# 1 2017-10-20 19:11:14+00:00          0         0
# 2 2017-10-20 14:52:39+00:00          0         0                    #HGX
# 3 2017-10-20 09:52:18+00:00          7         3
# 4 2017-10-20 07:01:38+00:00          0         1           #USGS08030500
#
#   Geolocation       user_split  \
# 0                 jimosborne98
# 1               timinhollywood
# 2                   iembot hgx
# 3                   NWSHouston
# 4              USGS TexasFlood
#
#                                            user_text
# 0  jimosborne98 Lol! The flood of lies just keeps...
# 1  timinhollywood Excuse me while I flood my time...
# 2  iembot hgx At 6:00 AM, 3 W League City [Galves...
# 3  NWSHouston Flash Flood Warning including Leagu...
# 4  USGS TexasFlood #USGS08030500 - Sabine Rv nr R...

# %%
df_0_IA['target']=0
df_0_IA.head()
# Out:
#               User                                               Text  \
# 0     jimosborne98      Lol! The flood of lies just keeps on rolling!
# 1   timinhollywood  Excuse me while I flood my timeline with Howar...
# 2       iembot_hgx  At 6:00 AM, 3 W League City [Galveston Co, TX]...
# 3       NWSHouston  Flash Flood Warning including League City TX, ...
# 4  USGS_TexasFlood  #USGS08030500 - Sabine Rv nr Ruliff, TX is abo...
#
#                        Date  Favorites  Retweets Mentions       Hashtags  \
# 0 2017-10-20 22:49:49+00:00          0         0
# 1 2017-10-20 19:11:14+00:00          0         0
# 2 2017-10-20 14:52:39+00:00          0         0                    #HGX
# 3 2017-10-20 09:52:18+00:00          7         3
# 4 2017-10-20 07:01:38+00:00          0         1           #USGS08030500
#
#   Geolocation       user_split  \
# 0                 jimosborne98
# 1               timinhollywood
# 2                   iembot hgx
# 3                   NWSHouston
# 4              USGS TexasFlood
#
#                                            user_text  target
# 0  jimosborne98 Lol! The flood of lies just keeps...       0
# 1  timinhollywood Excuse me while I flood my time...       0
# 2  iembot hgx At 6:00 AM, 3 W League City [Galves...       0
# 3  NWSHouston Flash Flood Warning including Leagu...       0
# 4  USGS TexasFlood #USGS08030500 - Sabine Rv nr R...       0

# %%
df_IA = pd.concat([df_1_IA, df_0_IA], axis = 0)

# %%
df_IA['location'] = 'IA'
df_IA.head()
# Out:
#            User                                               Text  \
# 0    iembot_grr  At 7:30 PM, 3 SW Clarksville [Ionia Co, MI] 91...
# 1  chriswhetlor  Alien Crop Circles, sign of the flood, or poss...
# 2       NickFry  Don't forget!!! TONIGHT! WV Flood Benefit Conc...
# 3    iembot_lwx  At 3:13 PM, 1 SW Breton BAY [St. Marys Co, MD]...
# 4  Mzzbesttbest  My Sisters keeps Telling me not to Flood and S...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-10-02 00:02:34+00:00          0         0              #GRR
# 1 2016-10-01 22:42:21+00:00          0         0
# 2 2016-10-01 21:52:44+00:00          0         0
# 3 2016-10-01 19:15:32+00:00          0         0              #LWX
# 4 2016-10-01 17:58:03+00:00          1         1
#
#   Geolocation    user_split  \
# 0                iembot grr
# 1              chriswhetlor
# 2                   NickFry
# 3                iembot lwx
# 4              Mzzbesttbest
#
#                                            user_text  target location
# 0  iembot grr At 7:30 PM, 3 SW Clarksville [Ionia...       0       IA
# 1  chriswhetlor Alien Crop Circles, sign of the f...       0       IA
# 2  NickFry Don't forget!!! TONIGHT! WV Flood Bene...       0       IA
# 3  iembot lwx At 3:13 PM, 1 SW Breton BAY [St. Ma...       1       IA
# 4  Mzzbesttbest My Sisters keeps Telling me not t...       0       IA

# %%
df_IA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1642 entries, 0 to 999
# Data columns (total 12 columns):
# User           1642 non-null object
# Text           1642 non-null object
# Date           1642 non-null datetime64[ns, UTC]
# Favorites      1642 non-null int64
# Retweets       1642 non-null int64
# Mentions       1642 non-null object
# Hashtags       1642 non-null object
# Geolocation    1642 non-null object
# user_split     1642 non-null object
# user_text      1642 non-null object
# target         1642 non-null int64
# location       1642 non-null object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 166.8+ KB

# %%
#df_IA.to_csv('df_IA.csv')

# %%
pd.read_csv('../Datasets/df_IA.csv')
# Out:
#       Unnamed: 0           User  \
# 0              0     TooCute504
# 1              1      juliakate
# 2              2  Slapfish_2009
# 3              3     AhleahZoe1
# 4              4      katyxbeth
# ...          ...            ...
# 1328         655      _ms_flood
# 1329         656     iembot_phi
# 1330         657     iembot_phi
# 1331         658  SuziWestModel
# 1332         659    RiptideBait
#
#                                                    Text  \
# 0     Took the time out to volunteer in BR today. Pe...
# 1     The great Paducah Flood Wall Murals... this At...
# 2     The Barman's Fund and USBG Tailgate Benefit fo...
# 3     Flood waters. @Downtown Burlington IA https://...
# 4     Last night sure was rainy as seen right before...
# ...                                                 ...
# 1328  Drinking a Athena Paradiso (Tart Cherry, Raspb...
# 1329  At 7:16 PM, Ocean City [Cape May Co, NJ] SOCIA...
# 1330  At 7:41 PM, 2 ENE Wildwood [Cape May Co, NJ] T...
# 1331  pushpushsalon was also effected by hurricane I...
# 1332  7:00 pm flood update . Brigantine NJ #riptideb...
#
#                            Date  Favorites  Retweets       Mentions  \
# 0     2016-10-02 23:06:20+00:00          0         0            NaN
# 1     2016-10-02 22:43:33+00:00          0         0            NaN
# 2     2016-10-02 20:32:22+00:00          0         0            NaN
# 3     2016-10-02 18:01:34+00:00          0         0            NaN
# 4     2016-10-02 17:54:06+00:00          0         0            NaN
# ...                         ...        ...       ...            ...
# 1328  2017-09-19 23:55:13+00:00          0         0  @creaturebeer
# 1329  2017-09-19 23:51:14+00:00          0         0            NaN
# 1330  2017-09-19 23:48:15+00:00          0         0            NaN
# 1331  2017-09-19 23:08:50+00:00          0         0            NaN
# 1332  2017-09-19 23:06:02+00:00          0         0            NaN
#
#                                                Hashtags  Geolocation  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                     #DrinkWithPurpose          NaN
# 3                                                   NaN          NaN
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 1328                                                NaN          NaN
# 1329                                               #PHI          NaN
# 1330                                               #PHI          NaN
# 1331                                                NaN          NaN
# 1332  #riptidebaitandtackle #brigantinenj #brigantin...          NaN
#
#          user_split                                          user_text  \
# 0        TooCute504  TooCute504 Took the time out to volunteer in B...
# 1         juliakate  juliakate The great Paducah Flood Wall Murals....
# 2     Slapfish 2009  Slapfish 2009 The Barman's Fund and USBG Tailg...
# 3        AhleahZoe1  AhleahZoe1 Flood waters. @Downtown Burlington ...
# 4         katyxbeth  katyxbeth Last night sure was rainy as seen ri...
# ...             ...                                                ...
# 1328       ms flood   ms flood Drinking a Athena Paradiso (Tart Che...
# 1329     iembot phi  iembot phi At 7:16 PM, Ocean City [Cape May Co...
# 1330     iembot phi  iembot phi At 7:41 PM, 2 ENE Wildwood [Cape Ma...
# 1331  SuziWestModel  SuziWestModel pushpushsalon was also effected ...
# 1332    RiptideBait  RiptideBait 7:00 pm flood update . Brigantine ...
#
#       target location
# 0          0       IA
# 1          0       IA
# 2          0       IA
# 3          1       IA
# 4          0       IA
# ...      ...      ...
# 1328       0       IA
# 1329       0       IA
# 1330       0       IA
# 1331       0       IA
# 1332       0       IA
#
# [1333 rows x 13 columns]

# %% [markdown]
# We used the combined data from this model to scrape the tweets.
