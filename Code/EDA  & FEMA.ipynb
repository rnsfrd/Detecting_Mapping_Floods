# %% [markdown]
# ## Client Project: Leveraging Social Media to Map Disasters

# %% [markdown]
# ## 1. EDA and FEMA Disaster Evaluation

# %% [markdown]
# ### Contents:
# - [Problem Statement](#Problem-Statement)
# - [Import Packages and Data](#Import-Packages-and-Data)
# - [EDA](#EDA)
#     - [FEMA](#FEMA)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# According to the National Oceanic and Atmospheric Administration (NOAA) the amount of billion dollar (adjusted for inflation) natural disasters per year since since 1980 has been on a steady uptrend with 3 of such events in 1980 and 14 in 2019. Although this number has increased dramatically for the United States as well as the rest of the world, the total number of deaths has fallen dramatically. Part of the reason for this is that people are able to recieve alerts and warnings much faster which allows them more time to prepare and evacuate. Many weather organizations have in place systems to alert the public about natural disasters and which areas are affected. But what if there are locations that are out of the system's reach? Can these weather systems always give precise mapping of a storm? What if power goes out in a widespread area causing a system to be delayed or innacurate? In the face of some of these challenges, social media, specifically Twitter, can be leveraged to accurately detect and map various types of natural disasters. Twitter allows us to search for tweets pertaining to the event we are looking to map as well as provide geolocation of where that tweet was sent from, and a timestamp of when the tweet was sent. Using these features we can build a model to validate and then map tweets pertaining to an event. This will ultimately allow for a more up to date service first responders can use to reach isolated civilians in the even of a crisis.

# %% [markdown]
# ### Import Packages and Data

# %%
import twitterscraper
from twitterscraper import query_tweets
import requests
import pandas as pd
import datetime as dt
import warnings
import requests
import regex as re
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer,HashingVectorizer,TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.tokenize import WordPunctTokenizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'}

# %%
#pip install GetOldTweets3

# %%
import GetOldTweets3 as got

# %%
#pip install twitterscraper

# %% [markdown]
# ## EDA

# %%
#reading in our scrapped Tweets 
df_wi_tx = pd.read_csv('../Datasets/df_TX_WI_clean.csv')

# %%
df_wi_tx.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Favorites', 'HashTags', 'Mentions', 'Retweets',
#        'Text', 'location', 'target', 'user_split', 'user_text'],
#       dtype='object')

# %%
df_wi_tx.shape
# Out:
# (2702, 11)

# %%
df_wi_tx['Text']
# Out:
# 0       Nice to have a positive story about big cats f...
# 1       my dad just told me to flood my car so I can g...
# 2                  Happy B-day Reggie, from the office!!!
# 3       Something about how crime will magically drop ...
# 4       Lol mine too. I’ve been avoiding floods for th...
#                               ...
# 2697    Flash flood watch for Charlotte and eastward u...
# 2698     Move to higher ground! Flash Flood Warning in...
# 2699    Help arrives for Greenspoint flood victi http:...
# 2700    W my fellow Capital Correspondents raising $fo...
# 2701    Flood party @Charleston, South Carolina https:...
# Name: Text, Length: 2702, dtype: object

# %%
df_wi_tx.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Favorites', 'HashTags', 'Mentions', 'Retweets',
#        'Text', 'location', 'target', 'user_split', 'user_text'],
#       dtype='object')

# %%
# create a month, year and date column 
from dateutil.parser import parse
df_wi_tx['Date'] = pd.to_datetime(df_wi_tx['Date'])

df_wi_tx['Month/Year'] = df_wi_tx['Date'].apply(lambda x: "%d/%d" % (x.month, x.year))

df_wi_tx['Month'] = df_wi_tx['Date'].apply(lambda x: "%d" % (x.month))

df_wi_tx['Year'] = df_wi_tx['Date'].apply(lambda x: "%d" % (x.year))

# %%
stop = list(stopwords.words('english'))

# %%
#created out own custom words 
custom = ['rf','com','lsr', 'edu', 'http' , 'www','usgs', 'instagram','pm', 'co', 'warning', 'amp', 'arx', 'cdt', 
         'ft', 'gov', 'uv', 'nw', 'tx', 'mngr', 'nwis']

# %%
# combine the stop with the custom
stop_final = stop + custom

# %%
# a function so we can see the frequency of words 
def word_count(list_words):
    cv = CountVectorizer(stop_words = stop_final)
    cv_transform= cv.fit_transform(list_words) # turning it into a vector
    df_word = pd.DataFrame(cv_transform.toarray(),
             columns=cv.get_feature_names()) # creating a dataframe
    df_sorted = pd.DataFrame(df_word.sum().sort_values(ascending=False),
                                  columns=['count'])
    return df_sorted

# %%
# a function to clean the words in the string columns
def cleaning_string(string):
    
    #We want letters only
    string = re.sub("[^a-zA-Z]", " ", string) 
    
    #removing hyperlinks
    string = re.sub(r'http\S+', '', string)
    string = re.sub(r'www\S+', '', string)
   
    #converts words to lowercase and splits.
    string = string.lower().split()
    
    #Instantiates lemmatizer and stems words.
    lemmatizer = WordNetLemmatizer()
    string = [lemmatizer.lemmatize(x) for x in string]
    
    #Creating variable form default english stopword list and our own custom stop list.
    stop = set(stopwords.words('english'))
    custom_stop = ['rf','com','lsr', 'edu', 'http' , 'www','usgs', 'co']
                   
    
    #removing stopwords from both the default english set, and our custom stop word list
    string = [x for x in string if not x in stop]
    string = [w for w in string if not w in custom_stop]
    

    #joining words separated by a space and return
    return(" ".join(string))

# %%
df_wi_tx['Text']= df_wi_tx['Text'].apply(cleaning_string)

# %%
df_count_wi_tx = word_count(df_wi_tx['Text'])

# %%
# top fifteen words found in the twitter 
df_count_wi_tx.head(15)
# Out:
#              count
# flood         2751
# flash         1080
# report         959
# mesonet        946
# iastate        943
# agron          943
# law            228
# enforcement    224
# stage          196
# including      195
# emergency      193
# site           193
# waterdata      192
# ground         180
# higher         179

# %% [markdown]
# The top words included the key words we searched for such as flood, flash, report. It also included environmental groups and weather organization sites (waterdata).

# %%
#looking at top tweets
df_count_wi_tx.head(15).plot(kind='barh',figsize=(10,10))
plt.title("Top 15 Words in Tweets", fontsize=28, fontweight='bold')
plt.gca().invert_yaxis()
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %% [markdown]
# Not suprising that flood and flash are the top words. Emergency, law, enforcement are all frewuent words expected to come up on the tweets. Waterdata is among the top 15 most frequent words - it is a online resource that provides acess to water resources data.

# %%
df_top_wi = df_count_wi_tx.head(10)

# %%
# top tweets in Wisconsin Floods
df_top_wi.head(15).plot(kind='barh',figsize=(12,12))
plt.title("Top 15 Words in Tweets", fontsize=28, fontweight='bold')
plt.gca().invert_yaxis()
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %% [markdown]
# The common word count was very similar to the combines wisconsin and texas data set.

# %%
df_IA_TX_WI_cleaned = pd.read_csv('../Datasets/df_IA_TX_WI_clean_adjusted.csv')
df_IA_TX_WI_cleaned.head()
# Out:
#    Unnamed: 0                       Date  Favorites HashTags       Mentions  \
# 0           0  2019-07-19 22:26:34+00:00          0     None           None
# 1           1  2019-07-19 22:19:05+00:00          1     None           None
# 2           2  2019-07-19 22:17:13+00:00          0     None           None
# 3           3  2019-07-19 20:57:18+00:00          0     None           None
# 4           4  2019-07-19 19:53:44+00:00          0     None  @RAGBRAI_IOWA
#
#    Retweets                                               Text location  \
# 0         0  my dad just told me to flood my car so I can g...       WI
# 1         2             Happy B-day Reggie, from the office!!!       WI
# 2         0  Something about how crime will magically drop ...       WI
# 3         0  Lol mine too. I’ve been avoiding floods for th...       WI
# 4         2  Riding the bus along I29 to @RAGBRAI_IOWA and ...       WI
#
#    target      user_split                                          user_text
# 0       0     chaaasiti04  chaaasiti04 my dad just told me to flood my ca...
# 1       0         JDenius     JDenius Happy B-day Reggie, from the office!!!
# 2       0   beganovic2021  beganovic2021 Something about how crime will m...
# 3       0  RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...
# 4       1         CajunCy  CajunCy Riding the bus along I29 to @RAGBRAI_I...

# %%
# drop 'Unnamed: 0' column
df_IA_TX_WI_cleaned.drop(columns=['Unnamed: 0'], inplace = True)

# %%
df_IA_TX_WI_cleaned.replace({'&amp;': 'and'},  inplace=True, regex=True)

# %%
df_1 = df_IA_TX_WI_cleaned[df_IA_TX_WI_cleaned['target']==1]
df_1
# Out:
#                            Date  Favorites HashTags       Mentions  Retweets  \
# 4     2019-07-19 19:53:44+00:00          0     None  @RAGBRAI_IOWA         2
# 6     2019-07-19 17:57:01+00:00          0     None           None         1
# 11    2019-07-19 13:53:26+00:00          1     None           None         0
# 14    2019-07-19 12:07:40+00:00          0     None           None         0
# 15    2019-07-19 12:07:39+00:00          0     None           None         0
# ...                         ...        ...      ...            ...       ...
# 2737  2016-09-21 12:16:01+00:00          1     #ARX           None         0
# 2738  2016-09-21 12:10:39+00:00          0     #CAR           None         0
# 2739  2016-09-21 12:06:10+00:00          0     #ARX           None         0
# 2740  2016-09-21 10:36:10+00:00          0     #ARX           None         0
# 2742  2016-09-21 04:59:29+00:00          1     None           None         1
#
#                                                    Text location  target  \
# 4     Riding the bus along I29 to @RAGBRAI_IOWA and ...       WI       1
# 6     https://kttc.com/news/top-stories/2019/07/19/h...       WI       1
# 11    At 6:15 PM CDT, 2 WNW Rolla [Phelps Co, MO] PU...       WI       1
# 14    At 3:00 AM CDT, Stockton [Winona Co, MN] EMERG...       WI       1
# 15    At 7:05 AM CDT, 2 NE Lewiston [Winona Co, MN] ...       WI       1
# ...                                                 ...      ...     ...
# 2737  At 7:10 AM, DE Soto [Crawford Co, WI] CO-OP OB...       IA       1
# 2738  At 6:45 PM, 5 NE Ashland [Aroostook Co, ME] DE...       IA       1
# 2739  At 7:04 AM, 3 ENE Pickwick [Winona Co, MN] LAW...       IA       1
# 2740  At 5:25 AM, 5 ENE Pickwick [Winona Co, MN] LAW...       IA       1
# 2742   Move to higher ground! Flash Flood Warning in...       IA       1
#
#          user_split                                          user_text
# 4           CajunCy  CajunCy Riding the bus along I29 to @RAGBRAI_I...
# 6         KttcKilat  KttcKilat https://kttc.com/news/top-stories/20...
# 11       iembot sgf  iembot sgf At 6:15 PM CDT, 2 WNW Rolla [Phelps...
# 14       iembot arx  iembot arx At 3:00 AM CDT, Stockton [Winona Co...
# 15       iembot arx  iembot arx At 7:05 AM CDT, 2 NE Lewiston [Wino...
# ...             ...                                                ...
# 2737     iembot arx  iembot arx At 7:10 AM, DE Soto [Crawford Co, W...
# 2738     iembot car  iembot car At 6:45 PM, 5 NE Ashland [Aroostook...
# 2739     iembot arx  iembot arx At 7:04 AM, 3 ENE Pickwick [Winona ...
# 2740     iembot arx  iembot arx At 5:25 AM, 5 ENE Pickwick [Winona ...
# 2742  NWSTwinCities  NWSTwinCities  Move to higher ground! Flash Fl...
#
# [1598 rows x 10 columns]

# %%
# function for cvec_df ngram(1,1)
def get_cvec_count(df_column): 
    cvec = CountVectorizer(lowercase=True, 
                       min_df = 2, 
                       max_df = .98,
                       max_features = 1000,
                       ngram_range = (1,1),
                       stop_words = 'english')
    X_cvec = cvec.fit_transform(df_column)
    X_cvec_df = pd.DataFrame(X_cvec.toarray(),
                          columns=cvec.get_feature_names())
    return X_cvec_df

# %%
X_cvec_df = get_cvec_count(df_1['Text'])

# %% [markdown]
# Below we analyzed the word frequecy of the tweets in the Iowa, Wisconsin and the Texas dataset. The common words are really similar for the 1 gram, 2 gram and 3 gram. The most common words are flood, weather organizations, environmental groups.  We kept http in because it was interesting to look at the websites that were mentioned in the tweets, the majority of the tweets linked to weather organizations website or a news source.

# %%
X_cvec_df_top = X_cvec_df.sum().sort_values(ascending = False).head(10)
X_cvec_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, N_Gram=(1,1)', fontsize = 22, fontweight= 'bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
# a function for the 2gram cvec
def get_cvec_count_2gram(df_column): 
    cvec = CountVectorizer(lowercase=True, 
                       min_df = 2, 
                       max_df = .98,
                       max_features = 1000,
                       ngram_range = (1,2),
                       stop_words = 'english')
    X_cvec = cvec.fit_transform(df_column)
    X_cvec_df = pd.DataFrame(X_cvec.toarray(),
                          columns=cvec.get_feature_names())
    return X_cvec_df

# %%
X_cvec_df = get_cvec_count_2gram(df_1['Text'])

# %%
X_cvec_df_top = X_cvec_df.sum().sort_values(ascending = False).head(10)
X_cvec_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, N_Gram=(1,2)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
#function for the 3 gram
def get_cvec_count_3gram(df_column): 
    cvec = CountVectorizer(lowercase=True, 
                       min_df = 2, 
                       max_df = .98,
                       max_features = 1000,
                       ngram_range = (1,3),
                       stop_words = 'english')
    X_cvec = cvec.fit_transform(df_column)
    X_cvec_df = pd.DataFrame(X_cvec.toarray(),
                          columns=cvec.get_feature_names())
    return X_cvec_df

# %%
X_cvec_df = get_cvec_count_3gram(df_1['Text'])

# %%
X_cvec_df_top = X_cvec_df.sum().sort_values(ascending = False).head(10)
X_cvec_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, N_Gram=(1,3)', fontsize = 22, fontweight= 'bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
df_TX_1 = df_1[df_1['location']=='TX']
df_IA_1 = df_1[df_1['location']=='IA']
df_WI_1 = df_1[df_1['location']=='WI']

# %%
X_cvec_TX_df=  get_cvec_count(df_TX_1['Text'])
X_cvec_IA_df= get_cvec_count(df_IA_1['Text'])
X_cvec_WI_df = get_cvec_count(df_WI_1['Text'])

# %%
X_cvec_TX_df_top = X_cvec_TX_df.sum().sort_values(ascending = False).head(10)
X_cvec_TX_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Texas, N_Gram=(1,1)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
X_cvec_IA_df_top = X_cvec_IA_df.sum().sort_values(ascending = False).head(10)
X_cvec_IA_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Iowa, N_Gram=(1,1)',fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
X_cvec_WI_df_top = X_cvec_WI_df.sum().sort_values(ascending = False).head(10)
X_cvec_WI_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Wisconsin, N_Gram=(1,1)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
X_cvec_TX_df=  get_cvec_count_2gram(df_TX_1['Text'])
X_cvec_IA_df= get_cvec_count_2gram(df_IA_1['Text'])
X_cvec_WI_df = get_cvec_count_2gram(df_WI_1['Text'])

# %%
X_cvec_TX_df_top = X_cvec_TX_df.sum().sort_values(ascending = False).head(10)
X_cvec_TX_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Texas, N_Gram=(1,2)', fontsize = 22, fontweight='bold')
plt.title('Top Feature Counts, Wisconsin, N_Gram=(1,1)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
X_cvec_IA_df_top = X_cvec_IA_df.sum().sort_values(ascending = False).head(10)
X_cvec_IA_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Iowa, N_Gram=(1,2)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %%
X_cvec_WI_df_top = X_cvec_WI_df.sum().sort_values(ascending = False).head(10)
X_cvec_WI_df_top.sort_values().plot(kind='barh', figsize = (10,7), fontsize = 14)
plt.title('Top Feature Counts, Wisconsin, N_Gram=(1,2)', fontsize = 22, fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold');

# %% [markdown]
# ## FEMA Data

# %% [markdown]
# In order to create a model that validated whether or not a tweet was really about a flood we needed to create data to train on. We used the OPENFema Dataset of Disaster Declaration Summaries to determine which flood tweets from which locations and time ranges would be assigned a target variable of '1' for 'flood' and which tweets would be assigned '0' for no flood or false positive.
#
# FEMA Disaster Declarations Summary is a dataset that stated all federally declared disasters. It containes information on whether any programs werer declared, the state in which it ocurred, disaster type and declaration date and incident begin and end date.
#
# Below we explored the data set,looked at all the unique titles and the date range for the flood.

# %%
df_FEMA_open_data = pd.read_csv('../Datasets/DisasterDeclarationsSummaries.csv')

# %%
df_FEMA_open_data.head()
# Out:
#    disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 0               1                  0                  1                  1
# 1               2                  0                  1                  1
# 2               3                  0                  1                  1
# 3               6                  0                  1                  1
# 4               4                  0                  1                  1
#
#    hmProgramDeclared state           declarationDate  fyDeclared disasterType  \
# 0                  1    GA  1953-05-02T00:00:00.000Z        1953           DR
# 1                  1    TX  1953-05-15T00:00:00.000Z        1953           DR
# 2                  1    LA  1953-05-29T00:00:00.000Z        1953           DR
# 3                  1    MI  1953-06-09T00:00:00.000Z        1953           DR
# 4                  1    MI  1953-06-02T00:00:00.000Z        1953           DR
#
#   incidentType                     title         incidentBeginDate  \
# 0      Tornado                   TORNADO  1953-05-02T00:00:00.000Z
# 1      Tornado  TORNADO & HEAVY RAINFALL  1953-05-15T00:00:00.000Z
# 2        Flood                     FLOOD  1953-05-29T00:00:00.000Z
# 3      Tornado                   TORNADO  1953-06-09T00:00:00.000Z
# 4      Tornado                   TORNADO  1953-06-02T00:00:00.000Z
#
#             incidentEndDate      disasterCloseOutDate declaredCountyArea  \
# 0  1953-05-02T00:00:00.000Z  1954-06-01T00:00:00.000Z                NaN
# 1  1953-05-15T00:00:00.000Z  1958-01-01T00:00:00.000Z                NaN
# 2  1953-05-29T00:00:00.000Z  1960-02-01T00:00:00.000Z                NaN
# 3  1953-06-09T00:00:00.000Z  1956-03-30T00:00:00.000Z                NaN
# 4  1953-06-02T00:00:00.000Z  1956-02-01T00:00:00.000Z                NaN
#
#    placeCode                              hash               lastRefresh  \
# 0        NaN  1dcb40d0664d22d39de787b706b0fa69  2019-07-26T18:08:57.368Z
# 1        NaN  61612cea5779e361b429799098974b6a  2019-07-26T18:08:57.370Z
# 2        NaN  86f3e47785cb7acc51364d4535d36101  2019-07-26T18:08:57.369Z
# 3        NaN  2208518c84c44f8e4164248d47f89ead  2019-07-26T18:08:57.369Z
# 4        NaN  1dbe5937a01fc74c8e699912e3f555cb  2019-07-26T18:08:57.370Z
#
#                          id
# 0  5d1bbd8c8bdcfa6efb32fd8d
# 1  5d1bbd8c8bdcfa6efb32fd8e
# 2  5d1bbd8c8bdcfa6efb32fd8f
# 3  5d1bbd8c8bdcfa6efb32fd92
# 4  5d1bbd8c8bdcfa6efb32fd91

# %%
df_FEMA_open_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51016 entries, 0 to 51015
# Data columns (total 19 columns):
# disasterNumber          51016 non-null int64
# ihProgramDeclared       51016 non-null int64
# iaProgramDeclared       51016 non-null int64
# paProgramDeclared       51016 non-null int64
# hmProgramDeclared       51016 non-null int64
# state                   51016 non-null object
# declarationDate         51016 non-null object
# fyDeclared              51016 non-null int64
# disasterType            51016 non-null object
# incidentType            51016 non-null object
# title                   51016 non-null object
# incidentBeginDate       51016 non-null object
# incidentEndDate         50503 non-null object
# disasterCloseOutDate    40999 non-null object
# declaredCountyArea      50802 non-null object
# placeCode               50802 non-null float64
# hash                    50943 non-null object
# lastRefresh             50943 non-null object
# id                      51016 non-null object
# dtypes: float64(1), int64(6), object(12)
# memory usage: 7.4+ MB

# %%
df_FEMA_open_data.dtypes
# Out:
# disasterNumber            int64
# ihProgramDeclared         int64
# iaProgramDeclared         int64
# paProgramDeclared         int64
# hmProgramDeclared         int64
# state                    object
# declarationDate          object
# fyDeclared                int64
# disasterType             object
# incidentType             object
# title                    object
# incidentBeginDate        object
# incidentEndDate          object
# disasterCloseOutDate     object
# declaredCountyArea       object
# placeCode               float64
# hash                     object
# lastRefresh              object
# id                       object
# dtype: object

# %%
df_fema_flood = df_FEMA_open_data[df_FEMA_open_data['incidentType'] == 'Flood']

# %%
df_fema_flood[df_fema_flood['incidentBeginDate']!=df_fema_flood['declarationDate']].tail(20)
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 50774            4459                  0                  0
# 50796            4461                  0                  0
# 50797            4466                  1                  0
# 50981            4475                  0                  0
# 50982            4475                  0                  0
# 50983            4475                  0                  0
# 50984            4475                  0                  0
# 50985            4475                  0                  0
# 50986            4475                  0                  0
# 50987            4475                  0                  0
# 50988            4475                  0                  0
# 50989            4475                  0                  0
# 50990            4475                  0                  0
# 50991            4475                  0                  0
# 50992            4475                  0                  0
# 50993            4475                  0                  0
# 50994            4475                  0                  0
# 50995            4475                  0                  0
# 50996            4475                  0                  0
# 50997            4475                  0                  0
#
#        paProgramDeclared  hmProgramDeclared state           declarationDate  \
# 50774                  1                  1    WI  2019-08-27T12:42:00.000Z
# 50796                  1                  1    IL  2019-09-19T09:53:00.000Z
# 50797                  0                  1    TX  2019-10-04T14:25:00.000Z
# 50981                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50982                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50983                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50984                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50985                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50986                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50987                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50988                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50989                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50990                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50991                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50992                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50993                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50994                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50995                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50996                  1                  1    ND  2020-01-21T12:17:00.000Z
# 50997                  1                  1    ND  2020-01-21T12:17:00.000Z
#
#        fyDeclared disasterType incidentType  \
# 50774        2019           DR        Flood
# 50796        2019           DR        Flood
# 50797        2020           DR        Flood
# 50981        2020           DR        Flood
# 50982        2020           DR        Flood
# 50983        2020           DR        Flood
# 50984        2020           DR        Flood
# 50985        2020           DR        Flood
# 50986        2020           DR        Flood
# 50987        2020           DR        Flood
# 50988        2020           DR        Flood
# 50989        2020           DR        Flood
# 50990        2020           DR        Flood
# 50991        2020           DR        Flood
# 50992        2020           DR        Flood
# 50993        2020           DR        Flood
# 50994        2020           DR        Flood
# 50995        2020           DR        Flood
# 50996        2020           DR        Flood
# 50997        2020           DR        Flood
df_FEMA_open_data[df_FEMA_open_data['disasterNumber']==4459].head()
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 50290            4459                  0                  0
# 50291            4459                  0                  0
# 50292            4459                  0                  0
# 50293            4459                  0                  0
# 50294            4459                  0                  0
#
#        paProgramDeclared  hmProgramDeclared state           declarationDate  \
# 50290                  1                  1    WI  2019-08-27T12:42:00.000Z
# 50291                  1                  1    WI  2019-08-27T12:42:00.000Z
# 50292                  1                  1    WI  2019-08-27T12:42:00.000Z
# 50293                  1                  1    WI  2019-08-27T12:42:00.000Z
# 50294                  1                  1    WI  2019-08-27T12:42:00.000Z
#
#        fyDeclared disasterType incidentType  \
# 50290        2019           DR        Flood
# 50291        2019           DR        Flood
# 50292        2019           DR        Flood
# 50293        2019           DR        Flood
# 50294        2019           DR        Flood
#
#                                                    title  \
# 50290  SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS,...
# 50291  SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS,...
# 50292  SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS,...
# 50293  SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS,...
# 50294  SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS,...
#
#               incidentBeginDate           incidentEndDate  \
# 50290  2019-07-18T00:00:00.000Z  2019-07-20T00:00:00.000Z
# 50291  2019-07-18T00:00:00.000Z  2019-07-20T00:00:00.000Z
# 50292  2019-07-18T00:00:00.000Z  2019-07-20T00:00:00.000Z
# 50293  2019-07-18T00:00:00.000Z  2019-07-20T00:00:00.000Z
# 50294  2019-07-18T00:00:00.000Z  2019-07-20T00:00:00.000Z
#
#       disasterCloseOutDate declaredCountyArea  placeCode  \
# 50290                  NaN                NaN        NaN
# 50291                  NaN    Barron (County)    99005.0
# 50292                  NaN    Vernon (County)    99123.0
# 50293                  NaN     Clark (County)    99019.0
# 50294                  NaN   Portage (County)    99097.0
#
#                                    hash               lastRefresh  \
# 50290  a8699eb216cb2ee05a7107b5ba7bf02c  2019-08-27T22:01:34.178Z
# 50291  8f0aa791f30ab798f332ef9dd29471f1  2019-10-10T19:57:09.215Z
# 50292  d51cfed668da13bc7c7a6b783f64c057  2019-10-10T19:57:09.143Z
# 50293  b226a2b4e8415db82e5587e6bf1cd2ca  2019-10-10T19:57:09.214Z
# 50294  44bf5a84b16c8054d3e98313218c0bdf  2019-10-10T19:57:09.213Z
#
#                              id
# 50290  5d65a83ef8b9013665b3a06d
# 50291  5d65acb8f8b9013665b3a35e
# 50292  5d65acb8f8b9013665b3a364
# 50293  5d65acb8f8b9013665b3a35f
# 50294  5d65acb8f8b9013665b3a360

# %%
df_FEMA_open_data.isnull().sum().sort_values(ascending = False)
# Out:
# disasterCloseOutDate    10017
# incidentEndDate           513
# placeCode                 214
# declaredCountyArea        214
# hash                       73
# lastRefresh                73
# id                          0
# state                       0
# ihProgramDeclared           0
# iaProgramDeclared           0
# paProgramDeclared           0
# hmProgramDeclared           0
# incidentType                0
# declarationDate             0
# fyDeclared                  0
# disasterType                0
# title                       0
# incidentBeginDate           0
# disasterNumber              0
# dtype: int64

# %%
WI = df_FEMA_open_data[df_FEMA_open_data['state'] == 'WI']

# %%
W__floods = WI[WI['disasterNumber']==4459]

# %% [markdown]
# We created month, year, and month/year columns so that we can filter through our dataset to find the dates for each state to scrape. We looked at date of each state in order to give a target of 1 for flood or zero if no flood.

# %%
#creating a month/year, and year column 
from dateutil.parser import parse
df_FEMA_open_data['incidentBeginDate'] = pd.to_datetime(df_FEMA_open_data['incidentBeginDate'])

df_FEMA_open_data['Month/Year'] = df_FEMA_open_data['incidentBeginDate'].apply(lambda x: "%d/%d" % (x.month, x.year))

df_FEMA_open_data['Month'] = df_FEMA_open_data['incidentBeginDate'].apply(lambda x: "%d" % (x.month))

df_FEMA_open_data['Year'] = df_FEMA_open_data['incidentBeginDate'].apply(lambda x: "%d" % (x.year))

# %%
df_FEMA_new = df_FEMA_open_data[df_FEMA_open_data['Year'] > '2005']

# %% [markdown]
# Since we are dealing with Twitter - we specifically wanted to look at dates that are older than 2005.

# %%
df_FEMA_month = df_FEMA_open_data['Month']

# %%
df_FEMA_open_data['Year'] = pd.to_datetime(df_FEMA_open_data['Year'])

# %%
# distribution graph of the years
df_FEMA_new['Year'].hist(figsize = (10,10), bins=13, edgecolor='k')
plt.title("Distribution of Disasters", fontsize=30,fontweight='bold')
plt.ylabel("Frequency Count", fontsize=20,fontweight='bold')
plt.xlabel("Year", fontsize=20,fontweight='bold')
plt.xticks(fontsize= 12,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.grid(False)
plt.show();

# %% [markdown]
# The FEMA datasets had disasters as far back as 953 however since we are leveraging social media - we only cared about more recent dates. This graph shows the distribution of the counts of disasters. The distribution shows that there were a lot more declared disasters between 2008 - 2009, 2011-2012 and between 2018-2019.

# %%
df_FEMA_open_data.to_csv('./df_fema.csv')

# %%
df_FEMA_open_data_flood = df_FEMA_open_data[df_FEMA_open_data['incidentType']=='Flood']

# %%
df_2015 = df_FEMA_open_data[df_FEMA_open_data['Month/Year']=='4/2015']

# %%
# look at more recent titles 
df_2015['title'].unique()
# Out:
# array(['SEVERE STORMS, TORNADOES, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE STORMS, FLOODING, LANDSLIDES, AND MUDSLIDES'], dtype=object)

# %%
df_FEMA_open_data_flood['title'].unique()
# Out:
# array(['FLOOD', 'FLOODS', 'FLOOD & EROSION', 'FLOOD & TORNADO',
#        'FLOODS & RAINS', 'STORM & FLOOD', 'HEAVY RAINSTORMS & FLOOD',
#        'HEAVY RAINSTORMS & FLOODS', 'HEAVY RAINS & FLOODS',
#        'FLOODS & TORNADOES', 'SEVERE STORM, HIGH TIDES & FLOODING',
#        'SEVERE STORMS, HIGH TIDES & FLOODING', 'ABNORMALLY HIGH TIDES',
#        'SEVERE STORMS & FLOODING',
#        'SEVERE STORMS, HEAVY RAINS & FLOODING', 'HEAVY RAINS & FLOODING',
#        'FLOODING', 'SEVERE STORMS, HIGH WINDS & FLOODING',
#        'HEAVY SNOWMELT, RAINS & FLOODING',
#        'SEVERE STORMS, ICE JAMS & FLOODING', 'HEAVY RAINS & FLASH',
#        'HEAVY RAINS, MELTING SNOWS & FLOODING', 'STORMS & FLOODING',
#        'HEAVY RAINS, HIGH WINDS & FLOODING', 'WINDS, FLOODING, MUDSLIDES',
#        'SEVERE STORMS & EXTENSIVE FLOODING', 'TROPICAL STORM AGNES',
#        'FLOODING CAUSED BY LEVEE BREAK',
#        'HIGH WINDS, WAVE ACTION & FLOODING',
#        'SEVERE STORMS, SNOW MELT & FLOODING',
#        'HEAVY RAINS, SNOWMELT AND FLOODING',
#        'SEVERE STORMS, FLOODING, & LANDSLIDES', 'FLOODING & LANDSLIDES',
#        'SEVERE STORMS, SNOWMELT & FLOODING',
#        'SEVERE STORMS, FLOODING & LANDSLIDES',
#        'HEAVY RAINS, SNOWMELT & FLOODING',
#        'SEVERE STORMS, LANDSLIDES & FLOODING',
#        'FLOODING FROM RAINS & SNOWMELT',
#        'RAINS, SHOWMELT, STORMS & FLOODING',
#        'HEAVY RAINS, HIGH WINDS, HAIL & TORNADOES',
#        'WINDS, TORNADOES, HEAVY RAINS & FLOODING',
#        'TROPICAL STORM ELIOISE', 'HIGH WINDS, HEAVY RAINS & FLOODING',
#        'STORMS, RAINS, LANDSLIDES & FLOODING',
#        'SEVERE STORMS, ICING, WIND & FLOODING', 'DAM COLLAPSE, FLOODING',
#        'FLASH FLOODING', 'FLASH FLOODING & MUDSLIDES',
#        'HIGH WINDS, FLASH FLOODS', 'SEVERE STORMS & FLASH FLOODING',
#        'FLOODING, TROPICAL STORM KATHLEEN',
#        'SEVERE STORMS, FLOODING & MUDSLIDES',
#        'SEVERE STORMS,MUDSLIDES, & FLOODING',
#        'SEVERE STORMS AND FLOODING',
#        'SEVERE STORMS, MUDSLIDES, LANDSLIDES & FLOODING',
#        'STORMS, MUD/LAND SLIDES, FLOODING', 'SEVERE STORMS',
#        'STORMS & FLASH FLOODS', 'STORMS, ICE JAMS, SNOWMELT & FLOODING',
#        'HEAVY RAINS, FLOODING & MUDSLIDES', 'STORMS, WIND, FLOODING',
#        'COASTAL STORMS & FLOODING', 'SEAWAVE ACTION & FLOODING',
#        'STORMS & FLASH FLOODING', 'SEVERE STORMS, MUDSLIDES & FLOODING',
#        'HEAVY RAINS, LANDSLIDES & FLOODING',
#        'STORMS, HIGH TIDES, MUDSLIDES & FLOODING',
#        'COASTAL STORMS, FLOOD, ICE & SNOW',
#        'FLOODING, MUDSLIDES & LANDSLIDES', 'TROPICAL STORM DANIELLE',
#        'SEVERE STORMS, FLOODING', 'COASTAL STORMS, MUDSLIDES & FLOODING',
#        'SEVERE STORMS, FLOOD, MUDSLIDES & HIGH TIDE',
#        'SEVERE STORMS, FLOODING &  MUDSLIDES',
#        'COASTAL STORM, HIGH WINDS & WAVES', 'TROPICAL STORM ALLISON',
#        'TROPICAL STORM CARMEN',
#        'HIGH WINDS, TIDAL SURGE & COASTAL FLOODING',
#        'SEVERE THUNDERSTORMS', 'SEVERE STORMS & HIGH TIDES',
#        'LEVEE BREAK', 'FLASH FLOOD DUE TO DAM FAILURE',
#        'SEVERE STORMS, HAIL & FLOODING', 'LANDSLIDES',
#        'COASTAL STORM, HIGH TIDES, HEAVY RAIN, & FLOODING',
#        'SEVERE STORMS, HIGH SURF & FLOODING',
#        'RAIN/SNOW/WIND STORMS, FLOODING, MUDSLIDES',
#        'SEVERE WINTER STORM, MUD & LAND SLIDES, & FLOODING',
#        'SEVERE FLOODING, SEVER WINTER STORMS,HEAVY RAINS HIGH WINDS',
#        'SEVERE FLOODING,SEVERE WINTER STORMS, SNOWMELT, SPRING RAINS',
#        'HIGH WINDS, SEVERE  STORMS AND FLOODING',
#        'HEAVY RAINS, FLASH FLOODS & MUD FLOWS', 'LEVEE BREAK & FLOODING',
#        'EXTENSIVE RAINFALL AND FLASH FLOODING',
#        'EXCESSIVE RAINFALL, HIGH WINDS, AND FLOODING',
#        'SEVERE STORMS,FLASH FLOODS', 'TROPICAL STORM AXEL',
#        'SEVERE COASTAL STORM', 'BLIZZARD OF 96', 'ICE JAMS AND FLOODING',
#        'FLOODING, HEAVY WINDS',
#        'SEVERE FLOODING, HIGH WINDS,SEVERE STORMS',
#        'SEVERE THUNDERSTORMS AND FLOODING',
#        'HEAVY RAIN, SNOWMELT & FLOODING',
#        'HEAVY RAIN, SNOWMELT, ICE JAMS & FLOODING',
#        'FLOODING AND SEVERE STORMS', 'HEAVY RAINS, ICE JAMS & FLOODING',
#        'SEVERE STORMS, TORNADOES & FLOODING',
#        'SEVERE STORMS, FLOODING, HIGH WINDS',
#        'WINTER STORM & COASTAL FLOODING',
#        'HIGH WINDS, SEVERE STORMS AND FLOODING',
#        'SEVERE STORMS, TORNADOES AND FLOODING',
#        'FLOODING, HIGH WINDS, AND WIND DRIVEN RAIN',
#        'HEAVY & WIND DRIVEN RAIN, HIGH WINDS,FLOODING,SLIDES',
#        'ICE JAMS & FLOODING',
#        'SEVERE WINDS AND FLOODING ASSOC WITH HURRICANE FRAN',
#        'SEVERE FLOODING', 'SEVERE STORMS, FLOODING, AND TORNADOES',
#        'THUNDERSTORMS, HAIL & FLOODING', 'HEAVY RAINS AND FLOODING',
#        'FALL NORTHEASTER RAINSTORM', 'FLOODING AND ICE JAMS',
#        'FLOODING, SEVERE STORMS, TORNADOES',
#        'FLOODING, LAND, MUD SLIDES, HIGH WINDS,SEVERE STORMS',
#        'SEVERE STORMS, FLOODING AND TORNADOES',
#        'EXTREME WEATHER CONDITONS AND FLOODING',
#        'FLOODING, SEVERE STORMS',
#        'SEVERE STORMS, FLOODING, & GROUND SATURATION',
#        'HEAVY RAINS, SNOW MELT, FLOODING, LAND & MUD SLIDES',
#        'SEVERE STORMS, HEAVY RAIN, FLASH FLOODS, FLOODING, MUDSLIDES',
#        'FLOODING ASSOCIATED WITH TROPICAL DEPRESSION FRAN',
#        'SEVERE WINTER STORMS, FLOODING, AND TORNADOES',
#        'FLOODING, SEVERE STORMS, AND LANDSLIDES', 'TX-FLOODING 10/18/98',
#        'SEVERE STORMS, FLOODING, SNOW, ICE, GROUND SATURATION, LANSLIDES, MUDSLIDES, AND TOR',
#        'FL00DING, SNOW MELT', 'FLOODING, SEVERE STORMS AND TORNADOES',
#        'SEVERE WINTER STORMS, FLOODING, AND ICE JAMS',
#        'WI-FLOOD-07/20/99', 'FLOODING, GROUND SATURATION,SEVERE STORMS',
#        'SEVERE STORM & FLOODING', 'DIKE FAILURE & FLASH FLOODING',
#        'PROLONGED AND HEAVY RAINS, HIGH SURF,FLOODING,LAND/MUD SLIDE',
#        'SEVERE THUNDERSTORMS AND FLASH FLOODING',
#        'TROPICAL DEPRESSION DENNIS PA', 'EXTREME RAINFALL AND FLOODING',
#        'FLOODING AND LANDSLIDES',
#        'SEVERE THUNDERSTORMS, HIGH WINDS,RAIN, FLOODING',
#        'SEVERE STORMS, ICE JAMS, AND FLOODING', 'ICE JAM AND FLOODING',
#        'SEVERE WINTER STORM, LANDSLIDES, MUDSLIDES, AND FLOODING',
#        'SEVERE STORMS, TORNADOES, AND FLOODING', 'TROPICAL STORM ALBERTO',
#        'RAIN, FLOODING, MUDSLIDE', 'REMNANTS OF TROPICAL STORM LEE',
#        'SEVERE WINTER STORMS, FLOODING, AND DEBRIS AND MUD FLOWS',
#        'SEVERE STORMS, FLOODING, TORNADOES, AND STRAIGHT-LINE WINDS',
#        'SEVERE WINTER STORM AND FLOODING',
#        'SEVERE STORMS, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'THREAT OF FLOODING AT SPIRIT LAKE',
#        'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS, AND FLOODING',
#        'SNOW MELT AND ICE JAM FLOODING', 'ICE JAM & FLOODING',
#        'SEVERE STORMS, FLOODING, MUDSLIDES, AND LANDSLIDES',
#        'EXTREME WEATHER CONDITIONS AND FLOODING',
#        'FLOODNG (NYS BARGE CANAL)', 'TROPICAL STORM LEE',
#        'SEVERE STORMS, STRAIGHT-LINE WINDS, AND FLOODING',
#        'SEVERE STORMS, STRAIGHT-LINE WINDS, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE STORMS, TORNADOES, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE WINTER STORM, SNOWSTORM, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE WINTER STORM, FLOODING, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE STORMS, FLOODING, AND MUDSLIDES',
#        'SEVERE WINTER STORMS, FLOODING, AND MUDSLIDES',
#        'SEVERE WINTER STORMS AND FLOODING',
#        'SEVERE STORMS, FLOODING, LANDSLIDES, MUDSLIDES',
#        'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS AND FLOODING',
#        'SEVERE WINTER STORM, STRAIGHT-LINE WINDS, FLOODING, LANDSLIDES, MUDSLIDES, AND A T',
#        'SEVERE STORMS, TORNADOES, STRAIGHT-LINE WINDS, FLOODING, AND LANDSLIDES',
#        'SEVERE WINTER STORMS, FLOODING, LANDSLIDES,  MUDSLIDES',
#        'SEVERE WINTER STORM, STRAIGHT-LINE WINDS, AND FLOODING',
#        'SEVERE STORM AND FLOODING',
#        'SEVERE WINTER STORM, SNOWSTORM, AND FLOODING',
#        'SEVERE STORMS, LANDSLIDES, AND MUDSLIDES',
#        'SEVERE STORMS, FLOODING, AND LANDSLIDES',
#        'SEVERE STORMS, STRAIGHT-LINE WINDS, TORNADOES, AND FLOODING',
#        'TROPICAL STORM IMELDA'], dtype=object)

# %% [markdown]
# This was necessary in deciding what key words to look at for the twitter scrapper. We scraped tweets with certain keywords that matched the unique title and that pertained to floods. When deciding on the date frame to look at we filtered by severe flood titles - we wanted to avoid storm or not severe storms from negatively impacting the model output.

# %%
#looking at these states that we will scrape from twitter 
df_NY = df_FEMA_open_data_flood[df_FEMA_open_data_flood['state'] == 'NY']
df_ME = df_FEMA_open_data_flood[df_FEMA_open_data_flood['state'] == 'ME']
df_CA = df_FEMA_open_data_flood[df_FEMA_open_data_flood['state'] == 'CA']
df_AK = df_FEMA_open_data_flood[df_FEMA_open_data_flood['state'] == 'AK']
df_ID = df_FEMA_open_data_flood[df_FEMA_open_data_flood['state'] == 'ID']

# %%
test = df_FEMA_open_data_flood[df_FEMA_open_data_flood['title']=='SEVERE STORMS AND FLOODING']
test['state'].value_counts()
# Out:
# TX    177
# IA    121
# LA     99
# PA     71
# NY     64
# NE     54
# MN     45
# SC     36
# AR     33
# IN     31
# MS     29
# IL     28
# SD     27
# MI     24
# VT     23
# MO     14
# OH     13
# ND     11
# NM     11
# ME     10
# OK      9
# MD      6
# TN      5
# FL      4
# WY      4
# HI      2
# NH      2
# WV      2
# AZ      2
# KS      1
# NV      1
# Name: state, dtype: int64

# %% [markdown]
# First states we investigated was Texas and Iowa. Texas and Iowa have the highest of floods with the title - 'SEVERE STORMS AND FLOODING'. We decided to scrape tweets from those states.

# %%
df_FEMA_open_data['title'].value_counts(normalize = True)
# Out:
# SEVERE STORMS AND FLOODING                0.074036
# SEVERE STORMS & FLOODING                  0.066391
# HURRICANE KATRINA EVACUATION              0.051004
# SEVERE WINTER STORM                       0.037929
# SEVERE STORMS, TORNADOES, AND FLOODING    0.035910
#                                             ...
# MOORE ROAD FIRE                           0.000020
# CAVE FIRE                                 0.000020
# MARTIN FIRE                               0.000020
# CARLTON COMPLEX FIRE                      0.000020
# CA-HOLLOW FIRE-07-14-2004                 0.000020
# Name: title, Length: 1812, dtype: float64

# %%
test[test['state']=='TX']['disasterNumber'].value_counts()
# Out:
# 4272    46
# 1425    41
# 4416    36
# 4269    27
# 1179    21
# 4454     3
# 4377     3
# Name: disasterNumber, dtype: int64

# %%
test[test['disasterNumber']== 4272];

# %%
TX_test = test[test['state']=='TX']
TX_test[TX_test['disasterNumber']==4272].describe()
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# count            46.0          46.000000               46.0
# mean           4272.0           0.521739                0.0
# std               0.0           0.505047                0.0
# min            4272.0           0.000000                0.0
# 25%            4272.0           0.000000                0.0
# 50%            4272.0           1.000000                0.0
# 75%            4272.0           1.000000                0.0
# max            4272.0           1.000000                0.0
#
#        paProgramDeclared  hmProgramDeclared  fyDeclared     placeCode
# count          46.000000          46.000000        46.0     46.000000
# mean            0.956522           0.934783      2016.0  99235.956522
# std             0.206185           0.249637         0.0    152.345070
# min             0.000000           0.000000      2016.0  99015.000000
# 25%             1.000000           1.000000      2016.0  99103.000000
# 50%             1.000000           1.000000      2016.0  99218.000000
# 75%             1.000000           1.000000      2016.0  99366.000000
# max             1.000000           1.000000      2016.0  99477.000000

# %% [markdown]
# Based on the data, the incident we will scrape tweets from:
# - TX
# - 2016
# - 5/22 - 6/24

# %%
#now looking at Texas in 2016 to decide dates where there weren't any floods 
report_2016 = df_FEMA_open_data[df_FEMA_open_data['Year']== '2016']

# %%
TX_2016 = report_2016[report_2016['state']=='TX']

# %%
TX_2016
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# 41252            4266                  0                  0
# 41259            4272                  1                  0
# 42010            4269                  0                  0
# 42257            4272                  0                  0
# 42743            4266                  1                  0
# ...               ...                ...                ...
# 49368            4269                  0                  0
# 49389            4272                  1                  0
# 49396            4272                  1                  0
# 49447            4269                  1                  0
# 49455            4269                  1                  0
#
#        paProgramDeclared  hmProgramDeclared state           declarationDate  \
# 41252                  1                  1    TX  2016-03-19T17:35:00.000Z
# 41259                  1                  1    TX  2016-06-11T13:23:00.000Z
# 42010                  1                  1    TX  2016-04-25T15:46:00.000Z
# 42257                  1                  0    TX  2016-06-11T13:23:00.000Z
# 42743                  1                  1    TX  2016-03-19T17:35:00.000Z
# ...                  ...                ...   ...                       ...
# 49368                  1                  1    TX  2016-04-25T15:46:00.000Z
# 49389                  1                  1    TX  2016-06-11T13:23:00.000Z
# 49396                  1                  1    TX  2016-06-11T13:23:00.000Z
# 49447                  1                  1    TX  2016-04-25T15:46:00.000Z
# 49455                  1                  1    TX  2016-04-25T15:46:00.000Z
#
#        fyDeclared disasterType incidentType  ...           incidentEndDate  \
# 41252        2016           DR        Flood  ...  2016-03-29T23:59:00.000Z
# 41259        2016           DR        Flood  ...  2016-06-24T23:59:00.000Z
# 42010        2016           DR        Flood  ...  2016-04-30T23:59:00.000Z
# 42257        2016           DR        Flood  ...  2016-06-24T23:59:00.000Z
# 42743        2016           DR        Flood  ...  2016-03-29T23:59:00.000Z
# ...           ...          ...          ...  ...                       ...
# 49368        2016           DR        Flood  ...  2016-04-30T23:59:00.000Z
# 49389        2016           DR        Flood  ...  2016-06-24T23:59:00.000Z
# 43056  5d1bbdb38bdcfa6efb33b588     9/2016     9 2016-01-01
# 43746  5d1bbdb38bdcfa6efb33b58b     9/2016     9 2016-01-01
# 43947  5d1bbdb38bdcfa6efb33b589     9/2016     9 2016-01-01
# 45090  5d1bbdb38bdcfa6efb33b592     9/2016     9 2016-01-01
# 45176  5d1bbdb38bdcfa6efb33b645     9/2016     9 2016-01-01
# 45975  5d1bbdb38bdcfa6efb33b644     9/2016     9 2016-01-01
# 46086  5d1bbdb38bdcfa6efb33b58e     9/2016     9 2016-01-01
# 46991  5d1bbdb38bdcfa6efb33b591     9/2016     9 2016-01-01
# 47161  5d1bbdb38bdcfa6efb33b643     9/2016     9 2016-01-01
# 47776  5d1bbdb38bdcfa6efb33b586     9/2016     9 2016-01-01
# 47809  5d1bbdb38bdcfa6efb33b583     9/2016     9 2016-01-01
# 48129  5d1bbdb38bdcfa6efb33b61d     9/2016     9 2016-01-01
# 48302  5d1bbdb38bdcfa6efb33b646     9/2016     9 2016-01-01
# 48951  5d1bbdb38bdcfa6efb33b649     9/2016     9 2016-01-01
# 49040  5d1bbdb38bdcfa6efb33b61f     9/2016     9 2016-01-01
# 49188  5d1bbdb38bdcfa6efb33b585     9/2016     9 2016-01-01
# 49338  5d1bbdb38bdcfa6efb33b590     9/2016     9 2016-01-01
# 49812  5d1bbdb38bdcfa6efb33b58c     9/2016     9 2016-01-01
#
# [19 rows x 22 columns]

# %% [markdown]
# Incident
# - Iowa
# - 2016
# - 9/21/16 - 10/3/16, y=1
# - 11/21/17-12/3/17, y=0

# %%
IA_test = test[test['state']=='IA']
IA_test.describe()
# Out:
#        disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# count      121.000000         121.000000         121.000000
# mean      3879.512397           0.082645           0.173554
# std       1132.765386           0.276489           0.380300
# min       1420.000000           0.000000           0.000000
# 25%       4289.000000           0.000000           0.000000
# 50%       4421.000000           0.000000           0.000000
# 75%       4421.000000           0.000000           0.000000
# max       4430.000000           1.000000           1.000000
#
#        paProgramDeclared  hmProgramDeclared   fyDeclared     placeCode
# count         121.000000              121.0   121.000000    121.000000
# mean            0.884298                1.0  2015.735537  98847.190083
# std             0.321198                0.0     6.361038   2681.584259
# min             0.000000                1.0  2002.000000  69600.000000
# 25%             1.000000                1.0  2017.000000  99043.000000
# 50%             1.000000                1.0  2019.000000  99087.000000
# 75%             1.000000                1.0  2019.000000  99135.000000
# max             1.000000                1.0  2019.000000  99197.000000

# %%
floods = df_FEMA_open_data[df_FEMA_open_data['incidentType']=='Flood']

# %%
floods_recent = floods[floods['Year'] > '2015']

# %% [markdown]
# ## EDA Visualizations

# %% [markdown]
# We looked at Frequency of Disaster, year and disaster, and the frequency of words used in titles.

# %%
df_top_disasters = df_FEMA_open_data.groupby(['incidentType']).size().sort_values(ascending=False).head(15)

# %%
df_top_disasters.plot(kind='barh', figsize = (10,10))
plt.gca().invert_yaxis()
plt.title("Frequency of Disaster", fontsize=28,fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Disaster", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 18,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %%
df_FEMA_open_data[['state','incidentType']].count()
# Out:
# state           51016
# incidentType    51016
# dtype: int64

# %% [markdown]
# We thought it would be interesting to see the breakdown of storms by month and by year.

# %%
df_FEMA_open_data.groupby(['Year', 'incidentType']).size().sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))
plt.gca().invert_yaxis()
plt.title("Year and Disaster", fontsize=28,fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Year, Disaster", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %% [markdown]
# The 2005 hurricane came up the most often. In addition to Katrina in 2005 there was alos Hurrican Rita and Wilma.

# %%
df_FEMA_open_data.groupby(['Month', 'incidentType']).size().sort_values(ascending=False).head(10).plot(kind='barh', figsize=(10,10))
plt.gca().invert_yaxis()
plt.title("Month and Disaster", fontsize=28,fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Month, Disaster", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %%
df_FEMA_open_data.groupby(['hmProgramDeclared', 'incidentType']).size().sort_values(ascending=False).head(15).plot(kind='barh', figsize=(10,10))
plt.gca().invert_yaxis()
plt.title("Program and Disaster", fontsize=28,fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Program, Disaster", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold');

# %% [markdown]
# This is a break down of the program and the type of storm.

# %%
df_FEMA_open_data_flood.groupby(['state']).size().sort_values(ascending=False).head(15).plot(kind='barh', figsize=(10,10))
plt.gca().invert_yaxis()
plt.title("State and Declared Flood", fontsize=28,fontweight='bold')
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("State", fontsize=24,fontweight='bold')
plt.yticks(fontsize= 20,fontweight='bold')
plt.xticks(fontsize= 20,fontweight='bold');

# %% [markdown]
# This graph shows a break down of state anf the type of storm with the frequency count. Mosourri and sever storms had the highest total storms.

# %%
df_top_words = word_count(df_FEMA_open_data['title']).head(15)

# %%
# top tweets in Wisconsin Floods
df_top_words.head(15).plot(kind='barh',figsize=(12,12))
plt.title("Top 15 Words", fontsize=28, fontweight='bold')
plt.gca().invert_yaxis()
plt.xlabel("Frequency Count", fontsize=26,fontweight='bold')
plt.ylabel("Word", fontsize=24,fontweight='bold')
plt.xticks(fontsize= 22,fontweight='bold')
plt.yticks(fontsize= 22,fontweight='bold')
plt.show();

# %% [markdown]
# The top words from the FEMA titles. Severe was the most frequent since we specifically looked at that in order to verify that it was a legitimate flood.
